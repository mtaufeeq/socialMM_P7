# %%
import pandas as pd

# %%
import glob

# %%
files = []
for file in glob.glob("/Users/jinwenxu/Downloads/WearMask_Tweets/*.csv"):
    files.append(file)

# %%
files
# Out:
# ['/Users/jinwenxu/Downloads/WearMask_Tweets/June_WearMask_Tweets.csv',
#  '/Users/jinwenxu/Downloads/WearMask_Tweets/September_WearMask_Tweets.csv',
#  '/Users/jinwenxu/Downloads/WearMask_Tweets/March_WearMask_Tweets.csv',
#  '/Users/jinwenxu/Downloads/WearMask_Tweets/May_WearMask_Tweets.csv',
#  '/Users/jinwenxu/Downloads/WearMask_Tweets/November_WearMask_Tweets.csv',
#  '/Users/jinwenxu/Downloads/WearMask_Tweets/August_WearMask_Tweets.csv',
#  '/Users/jinwenxu/Downloads/WearMask_Tweets/October_WearMask_Tweets.csv',
#  '/Users/jinwenxu/Downloads/WearMask_Tweets/July_WearMask_Tweets.csv',
#  '/Users/jinwenxu/Downloads/WearMask_Tweets/April_WearMask_Tweets.csv']

# %%
files[0]
# Out:
# '/Users/jinwenxu/Downloads/WearMask_Tweets/June_WearMask_Tweets.csv'

# %%
for file in files:
    df_temp = pd.read_csv(file)
    if file == files[0]:
        df = df_temp
    else:
        df = df.append(df_temp)

# %%
df.head()
# Out:
#                                           Tweet Text       Tweet Datetime  \
# 0  @JuliaDavisNews Saddam hid like a rat in a hol...  2020-06-01 00:01:07
# 1  https://t.co/8rXvRFd4UZ via @zazzle #facemask ...  2020-06-01 00:05:50
# 2  Philippines morning news for June 1\n\nvia @ae...  2020-06-01 00:06:02
# 3  #FiqueEmCasa #UseMáscara #Stayhouse #WearAMask...  2020-06-01 00:07:10
# 4  Lao morning news for June 1\n\nvia @aecnewstod...  2020-06-01 00:17:00
#
#               Tweet Id              User Id        User Name  \
# 0  1267244750186389511  1257861410928943106    DotarSojat429
# 1  1267245938139168769             80475492        elenafdzz
# 2  1267245987493543939           3265583034     AecNewsToday
# 3  1267246274115485697  1220482934056136704  Ricardo04972514
# 4  1267248745869193217           3265583034     AecNewsToday
#
#                       User Location Tweet Coordinates Place Info Country  \
# 0                            Jasoom               NaN        NaN     NaN
# 1  in the middle of the Rainforest!               NaN        NaN     NaN
# 2                          Cambodia               NaN        NaN     NaN
# 3                               NaN               NaN        NaN     NaN
# 4                          Cambodia               NaN        NaN     NaN
#
#                                             Hashtags  Retweets  Favorites  \
# 0                                      ['WearAMask']        11         48
# 1  ['facemask', 'musthave', 'style', 'fashion', '...         0          0
# 2  ['Independent', 'Asean', 'journalism', 'Cambod...         5          0
# 3  ['FiqueEmCasa', 'UseMáscara', 'Stayhouse', 'We...         0          0
# 4  ['Independent', 'Asean', 'journalism', 'Cambod...         5          0
#
#   Language               Source  Replied Tweet Id  Replied Tweet User Id
# 0       en  Twitter for Android      1.267243e+18            105327432.0
# 1      und      Twitter Web App               NaN                    NaN
# 2       en               Buffer               NaN                    NaN
# 3       pt  Twitter for Android               NaN                    NaN
# 4       en               Buffer               NaN                    NaN

# %%
df_test = df[~pd.isna(df['User Location'])][['User Location']]

# %%
len(pd.unique(df[~pd.isna(df['User Location'])]['User Location']))
# Out:
# 14431

# %%
data = pd.DataFrame(pd.unique(df[~pd.isna(df['User Location'])]['User Location']))

# %%
data["Lat"] = ""
data["Lon"] = ""

# %%
data.columns = ['location', 'Lat','Lon']

# %%
data['index'] = data.index

# %%
data = data[['index','location','Lat','Lon']]

# %%
# geocoding step !!!do not run!!! (cost credits)
import csv
from geopy.geocoders import GoogleV3
from geopy.exc import GeocoderTimedOut
from geopy.exc import GeocoderServiceError
import time
import tkinter as tk
from tkinter.filedialog import askdirectory
from pathlib import Path

def do_geocode(address, n):
    if n > 0:
        try:
            return geolocator.geocode(address)
        except GeocoderTimedOut:
            return do_geocode(address, n-1)
        except GeocoderServiceError:
            time.sleep(10)
    else:
        return None

#inputpath = Path(askdirectory())

# change the input file name
# with open(str(inputpath)+"\\user_location_unique.csv") as f:
#     reader = csv.DictReader(f)
#     data = [r for r in reader]

# be sure to make the csv file according to the format below
keys = ['index','location','Lat','Lon']
#keys = ['Name','County','Population', 'State','St_abbr','user_location','Lat','Lon']

# inputpath = "H:/Night_light_data/Hurricane Sandy/Windspeed/"


#input the key (the key here is omitted since it is linked to credit card.)
geolocator = GoogleV3(api_key = "")

geocode_location = pd.DataFrame(columns = keys)
for index,line in data.iterrows():
    location = do_geocode(line["location"], 1)
    if location is not None:
        line["Lat"] = location.latitude
        line["Lon"] = location.longitude
        print (line)
    geocode_location = geocode_location.append(line)
# Out:
# index              2
# location    Cambodia
# Lat          12.5657
# Lon          104.991
# Name: 2, dtype: object
# index                      3
# location     Guelph, Ontario
# Lat                  43.5448
# Lon                 -80.2482
# Name: 3, dtype: object
# index                 4
# location    Burbank, CA
# Lat             34.1808
# Lon            -118.309
# Name: 4, dtype: object
# index                5
# location    Howell, MI
# Lat            42.6073
# Lon           -83.9294
# Name: 5, dtype: object
# index             6
# location     Ottawa
# Lat         45.4215
# Lon        -75.6972
# Name: 6, dtype: object
# index                         7
# location    North Carolina, USA
# Lat                     35.7596
# Lon                    -79.0193
# Name: 7, dtype: object
# index                       8
# location    Greater Vancouver
# Lat                   49.2501
# Lon                  -123.082
# Name: 8, dtype: object
# index                   9
# location    Colorado, USA
# Lat               39.5501
# Lon              -105.782
# Name: 9, dtype: object
# index            10
# location        NYC
# Lat         40.7128
# Lon         -74.006
# Name: 10, dtype: object
# index                           11
# location    Chesterfield, Virginia
# Lat                        37.3771
# Lon                        -77.505
# Name: 11, dtype: object
# index                  12
# location    Illinois, USA
# Lat               40.6331
# Lon              -89.3985
# Name: 12, dtype: object
# index            13
# location        SW1
# Lat          49.251
# Lon        -123.003
# Name: 13, dtype: object
# index             14
# location    New York
# Lat          40.7128
# Lon          -74.006
# Name: 14, dtype: object
# index            15
# location    Chicago
# Lat         41.8781
# Lon        -87.6298
# Name: 15, dtype: object
# index                    16
# location    California, USA
# Lat                 36.7783
# Lon                -119.418
# Name: 16, dtype: object
# index                      17
# location    Sangareddy, India
# Lat                    17.614
# Lon                   78.0816
# Name: 17, dtype: object
# index               18
# location    Whitby, ON
# Lat            43.8975
# Lon           -78.9429
# Name: 18, dtype: object
# index                19
# location    New England
# Lat             43.9654
# Lon            -70.8227
# Name: 19, dtype: object
# index            20
# location      Tahoe
# Lat         39.0968
# Lon        -120.032
# Name: 20, dtype: object
# index                               21
# location    Baltimore MD Citizen 2012
# Lat                            39.2904
# Lon                           -76.6122
# Name: 21, dtype: object
# index                      22
# location    Santiago de Chile
# Lat                  -33.4489
# Lon                  -70.6693
# Name: 22, dtype: object
# index             23
# location    Illinois
# Lat          40.6331
# Lon         -89.3985
# Name: 23, dtype: object
# index                   24
# location    Northeast Ohio
# Lat                41.2618
# Lon               -81.1637
# Name: 24, dtype: object
# index            25
# location    Arizona
# Lat         34.0489
# Lon        -111.094
# Name: 25, dtype: object
# index                  26
# location    United States
# Lat               37.0902
# Lon              -95.7129
# Name: 26, dtype: object
# index            27
# location        USA
# Lat         37.0902
# Lon        -95.7129
# Name: 27, dtype: object
# index                  28
# location    Mumbai, India
# Lat                19.076
# Lon               72.8777
# Name: 28, dtype: object
# index                                30
# location    The Hudson Valley, New York
# Lat                             41.9209
# Lon                            -73.9613
# Name: 30, dtype: object
# index                  31
# location    Bhopal, India
# Lat               23.2599
# Lon               77.4126
# Name: 31, dtype: object
# index            32
# location    Lucknow
# Lat         26.8467
# Lon         80.9462
# Name: 32, dtype: object
# index                33
# location    Oakland, CA
# Lat             37.8044
# Lon            -122.271
# Name: 33, dtype: object
# index                      34
# location    St Petersburg, FL
# Lat                   27.7676
# Lon                  -82.6403
# Name: 34, dtype: object
# index                            35
# location    Cape Town, South Africa
# Lat                        -33.9249
# Lon                         18.4241
# Name: 35, dtype: object
# index               36
# location    Newark, NJ
# Lat            40.7357
# Lon           -74.1724
# Name: 36, dtype: object
# index             37
# location     Bungoma
# Lat         0.569525
# Lon          34.5584
# Name: 37, dtype: object
# index                   38
# location    Nairobi, Kenya
# Lat               -1.29207
# Lon                36.8219
# Name: 38, dtype: object
# index                     39
# location    Sambalpur, India
# Lat                  21.4669
# Lon                  83.9812
# Name: 39, dtype: object
# index            40
# location    she/her
# Lat          37.032
# Lon        -95.6234
# Name: 40, dtype: object
# index                                41
# location    Jinja road, Industrial Area
# Lat                            0.317299
# Lon                             32.5942
# Name: 41, dtype: object
# index                        42
# location     The #UK 🇬🇧 and 🇪🇺
# Lat                     55.3781
# Lon                    -3.43597
# Name: 42, dtype: object
# index                          43
# location    Table View, Cape Town
# Lat                      -33.8218
# Lon                       18.4915
# Name: 43, dtype: object
# index                   44
# location    Abuja, Nigeria
# Lat                9.07648
# Lon                7.39857
# Name: 44, dtype: object
# index                     45
# location    New Delhi, India
# Lat                  28.6139
# Lon                   77.209
# Name: 45, dtype: object
# index                  46
# location    New York City
# Lat               40.7128
# Lon               -74.006
# Name: 46, dtype: object
# index                         47
# location    Suan Luang, Thailand
# Lat                      13.7355
# Lon                      100.641
# Name: 47, dtype: object
# index                     49
# location    Natchitoches, LA
# Lat                  31.7607
# Lon                 -93.0863
# Name: 49, dtype: object
# index                    50
# location    Kampala, Uganda
# Lat                0.347596
# Lon                 32.5825
# Name: 50, dtype: object
# index                    51
# location    London, England
# Lat                 51.5074
# Lon               -0.127758
# Name: 51, dtype: object
# index            52
# location    Nigeria
# Lat           9.082
# Lon         8.67528
# Name: 52, dtype: object
# index                                  53
# location    Soler 458, Ituzaingo, Bs. As.
# Lat                               -34.656
# Lon                              -58.6693
# Name: 53, dtype: object
# index               54
# location    Texas, USA
# Lat            31.9686
# Lon           -99.9018
# Name: 54, dtype: object
# index                  56
# location    New York, USA
# Lat               40.7128
# Lon               -74.006
# Name: 56, dtype: object
# index                57
# location    Yonkers, NY
# Lat             40.9312
# Lon            -73.8987
# Name: 57, dtype: object
# index                           58
# location    ネット予約⬇️群馬県 高崎市江木町1502
# Lat                        36.3315
# Lon                        139.028
# Name: 58, dtype: object
# index            59
# location     Canada
# Lat         56.1304
# Lon        -106.347
# Name: 59, dtype: object
# index                        60
# location    Manchester, England
# Lat                     53.4808
# Lon                    -2.24263
# Name: 60, dtype: object
# index                                         61
# location    New York Metro/ Hudson Valley Region
# Lat                                      41.9209
# Lon                                     -73.9613
# Name: 61, dtype: object
# index                    62
# location    Medley, Florida
# Lat                 25.8407
# Lon                -80.3264
# Name: 62, dtype: object
# index            63
# location    Toronto
# Lat         43.6532
# Lon        -79.3832
# Name: 63, dtype: object
# index                        64
# location    Auderghem, Belgique
# Lat                     50.8164
# Lon                     4.42652
# Name: 64, dtype: object
# index                    65
# location    Minneapolis, MN
# Lat                 44.9778
# Lon                 -93.265
# Name: 65, dtype: object
# index                 66
# location    Surprise, AZ
# Lat              33.6292
# Lon             -112.368
# Name: 66, dtype: object
# index                67
# location    Kansas City
# Lat             39.0997
# Lon            -94.5786
# Name: 67, dtype: object
# index            68
# location         LA
# Lat         34.0522
# Lon        -118.244
# Name: 68, dtype: object
# index                  69
# location    Whitefish, MT
# Lat               48.4106
# Lon              -114.335
# Name: 69, dtype: object
# index              70
# location    Scotland
# Lat           56.4907
# Lon          -4.20265
# Name: 70, dtype: object
# index                     71
# location    Lahore, Pakistan
# Lat                  31.5204
# Lon                  74.3587
# Name: 71, dtype: object
# index                     72
# location    Toronto, Ontario
# Lat                  43.6532
# Lon                 -79.3832
# Name: 72, dtype: object
# index            73
# location      80207
# Lat         39.7619
# Lon        -104.921
# Name: 73, dtype: object
# index               74
# location    USA+LAHORE
# Lat            31.5332
# Lon            74.3792
# Name: 74, dtype: object
# index                                   75
# location    London City Island aka Eastend
# Lat                                 51.512
# Lon                              0.0055131
# Name: 75, dtype: object
# index                            76
# location    England, United Kingdom
# Lat                         52.3555
# Lon                        -1.17432
# Name: 76, dtype: object
# index              77
# location    MANHATTAN
# Lat           40.7831
# Lon          -73.9712
# Name: 77, dtype: object
# index                                 78
# location    Venice, Florida (Paradise) 🏖
# Lat                                27.11
# Lon                             -82.4249
# Name: 78, dtype: object
# index                              79
# location    34,Parkstreet ,Kolkata 16
# Lat                           22.5487
# Lon                           88.3572
# Name: 79, dtype: object
# index            81
# location      Tokyo
# Lat         35.6762
# Lon          139.65
# Name: 81, dtype: object
# index              82
# location    Miami, FL
# Lat           25.7617
# Lon          -80.1918
# Name: 82, dtype: object
# index                               84
# location    Los Angeles, CA London UK
# Lat                            34.0595
# Lon                           -118.414
# Name: 84, dtype: object
# index              85
# location    Worldwide
# Lat           40.0421
# Lon          -76.3888
# Name: 85, dtype: object
# index                     86
# location    New England, USA
# Lat                  43.9654
# Lon                 -70.8227
# Name: 86, dtype: object
# index               88
# location    Boston, MA
# Lat            42.3601
# Lon           -71.0589
# Name: 88, dtype: object
# index                  89
# location    Massachusetts
# Lat               42.4072
# Lon              -71.3824
# Name: 89, dtype: object
# index                 90
# location    Florida, USA
# Lat              27.6648
# Lon             -81.5158
# Name: 90, dtype: object
# index                91
# location    Oregon, USA
# Lat             43.8041
# Lon            -120.554
# Name: 91, dtype: object
# index                     92
# location    Northern Ireland
# Lat                  54.7877
# Lon                 -6.49231
# Name: 92, dtype: object
# index                     93
# location    Connecticut, USA
# Lat                  41.6032
# Lon                 -73.0877
# Name: 93, dtype: object
# index                    94
# location    Crystal Lake IL
# Lat                 42.2411
# Lon                -88.3162
# Name: 94, dtype: object
# index                         95
# location    Salt lake city, Utah
# Lat                      40.7608
# Lon                     -111.891
# Name: 95, dtype: object
# index                   97
# location    Washington, DC
# Lat                38.9072
# Lon               -77.0369
# Name: 97, dtype: object
# index                  98
# location    Manhattan, NY
# Lat               40.7831
# Lon              -73.9712
# Name: 98, dtype: object
# index                99
# location    Bothell, WA
# Lat             47.7601
# Lon            -122.205
# Name: 99, dtype: object
# index                100
# location    South Africa
# Lat             -30.5595
# Lon              22.9375
# Name: 100, dtype: object
# index               101
# location    Minneapolis
# Lat             44.9778
# Lon             -93.265
# Name: 101, dtype: object
# index                 102
# location    Virginia, USA
# Lat               37.4316
# Lon              -78.6569
# Name: 102, dtype: object
# index             103
# location    Vancouver
# Lat           49.2827
# Lon          -123.121
# Name: 103, dtype: object
# index               104
# location    Los Angeles
# Lat             34.0522
# Lon            -118.244
# Name: 104, dtype: object
# index                 106
# location    St. Louis, MO
# Lat                38.627
# Lon              -90.1994
# Name: 106, dtype: object
# index                107
# location    Alabama, USA
# Lat              32.3182
# Lon             -86.9023
# Name: 107, dtype: object
# index                       108
# location    Bulawayo, Zimbabwe.
# Lat                    -20.1457
# Lon                     28.5873
# Name: 108, dtype: object
# index              109
# location    NY, NY USA
# Lat            40.7128
# Lon            -74.006
# Name: 109, dtype: object
# index                110
# location    New York, NY
# Lat              40.7128
# Lon              -74.006
# Name: 110, dtype: object
# index                     111
# location    Oklahoma City, OK
# Lat                   35.4676
# Lon                  -97.5164
# Name: 111, dtype: object
# index                    112
# location    Portland, Oregon
# Lat                  45.5051
# Lon                 -122.675
# Name: 112, dtype: object
# index                      113
# location    Hammond, Louisiana
# Lat                    30.5044
# Lon                   -90.4612
# Name: 113, dtype: object
# index           114
# location         VA
# Lat         36.0986
# Lon        -94.1571
# Name: 114, dtype: object
# index           115
# location      earth
# Lat         37.2321
# Lon        -95.7243
# Name: 115, dtype: object
# index                   116
# location    Western NewYork
# Lat                 43.3447
# Lon                -75.3879
# Name: 116, dtype: object
# index                     117
# location    Philadelphia, USA
# Lat                   39.9526
# Lon                  -75.1652
# Name: 117, dtype: object
# index             118
# location    Ohio, USA
# Lat           40.4173
# Lon          -82.9071
# Name: 118, dtype: object
# index                     119
# location    Manhattan, Malibu
# Lat                   40.7059
# Lon                  -74.0018
# Name: 119, dtype: object
# index                                 120
# location    Province of Leningrad, Russia
# Lat                               60.0793
# Lon                               31.8927
# Name: 120, dtype: object
# index                                         121
# location    On the tundra in Rochester, Minnesota
# Lat                                       43.9591
# Lon                                       -92.464
# Name: 121, dtype: object
# index                122
# location    Arizona, USA
# Lat              34.0489
# Lon             -111.094
# Name: 122, dtype: object
# index                    123
# location    Allahabad, India
# Lat                  25.4358
# Lon                  81.8463
# Name: 123, dtype: object
# index                  124
# location    Lucknow, India
# Lat                26.8467
# Lon                80.9462
# Name: 124, dtype: object
# index                 125
# location    Amethi, India
# Lat               26.1541
# Lon               81.8142
# Name: 125, dtype: object
# index           126
# location    aburoad
# Lat         24.4641
# Lon         72.7718
# Name: 126, dtype: object
# index                    127
# location    Gorakhpur, India
# Lat                  26.7606
# Lon                  83.3732
# Name: 127, dtype: object
# index                                  128
# location    Kunda, Pratapgarh उत्तर प्रदेश
# Lat                                25.7175
# Lon                                81.5212
# Name: 128, dtype: object
# index                          129
# location    Pune University, India
# Lat                        18.5524
# Lon                        73.8267
# Name: 129, dtype: object
# index                     130
# location    Meerut, UP, INDIA
# Lat                   28.9845
# Lon                   77.7064
# Name: 130, dtype: object
# index                   131
# location    Bhilwara, India
# Lat                 25.3407
# Lon                 74.6313
# Name: 131, dtype: object
# index                             132
# location    Kota Surabaya, Jawa Timur
# Lat                          -7.25747
# Lon                           112.752
# Name: 132, dtype: object
# index                              133
# location    up India (बाशिंदा बिहार का
# Lat                            26.8467
# Lon                            80.9462
# Name: 133, dtype: object
# index                134
# location    Kent G.B. 🇬🇧
# Lat              51.2787
# Lon             0.521725
# Name: 134, dtype: object
# index            135
# location    Scotland
# Lat          56.4907
# Lon         -4.20265
# Name: 135, dtype: object
# index                        136
# location    Uttar Pradesh, India
# Lat                      26.8467
# Lon                      80.9462
# Name: 136, dtype: object
# index                  137
# location    Kolkata, India
# Lat                22.5726
# Lon                88.3639
# Name: 137, dtype: object
# index                                 138
# location    FIROZABADUttar Pradesh, India
# Lat                               27.1592
# Lon                               78.3957
# Name: 138, dtype: object
# index                    139
# location    Kaushambi, India
# Lat                  25.3611
# Lon                  81.4032
# Name: 139, dtype: object
# index               140
# location    Bhubaneswar
# Lat             20.2961
# Lon             85.8245
# Name: 140, dtype: object
# index                141
# location    Philadelphia
# Lat              39.9526
# Lon             -75.1652
# Name: 141, dtype: object
# index                    142
# location    Scienceville, NC
# Lat                  41.1137
# Lon                 -80.6167
# Name: 142, dtype: object
# index                            143
# location    ÜT: 38.975121,-76.888847
# Lat                          30.2849
# Lon                         -97.7341
# Name: 143, dtype: object
# index                 144
# location    Kentucky, USA
# Lat               37.8393
# Lon                -84.27
# Name: 144, dtype: object
# index                    145
# location    Gaithersburg, MD
# Lat                   39.144
# Lon                 -77.2016
# Name: 145, dtype: object
# index           146
# location       U.K.
# Lat         55.3781
# Lon        -3.43597
# Name: 146, dtype: object
# index           147
# location      Noida
# Lat         28.5355
# Lon          77.391
# Name: 147, dtype: object
# index                   148
# location    Ohio & Michigan
# Lat                 41.5811
# Lon                 -83.545
# Name: 148, dtype: object
# index               149
# location    Hoboken, NJ
# Lat              40.744
# Lon            -74.0324
# Name: 149, dtype: object
# index                       150
# location    The Gem State Idaho
# Lat                     44.0682
# Lon                    -114.742
# Name: 150, dtype: object
# index           151
# location      Texas
# Lat         31.9686
# Lon        -99.9018
# Name: 151, dtype: object
# index                          152
# location    Boothbay Harbor, Maine
# Lat                        43.8523
# Lon                       -69.6281
# Name: 152, dtype: object
# index               153
# location    Kansas, USA
# Lat             39.0119
# Lon            -98.4842
# Name: 153, dtype: object
# index                     154
# location    Traverse City, MI
# Lat                   44.7631
# Lon                  -85.6206
# Name: 154, dtype: object
# index               155
# location    Seattle, WA
# Lat             47.6062
# Lon            -122.332
# Name: 155, dtype: object
# index                        156
# location    Champaign/Urbana, Il
# Lat                      40.1164
# Lon                     -88.2434
# Name: 156, dtype: object
# index                     157
# location    Windsor Locks, CT
# Lat                   41.9243
# Lon                  -72.6454
# Name: 157, dtype: object
# index            158
# location    Perry,NY
# Lat          42.7156
# Lon         -78.0056
# Name: 158, dtype: object
# index               159
# location    Canton Ohio
# Lat             40.7989
# Lon            -81.3784
# Name: 159, dtype: object
# index                     160
# location    Fort Worth, Texas
# Lat                   32.7555
# Lon                  -97.3308
# Name: 160, dtype: object
# index                          161
# location    Traverse City Michigan
# Lat                        44.7631
# Lon                       -85.6206
# Name: 161, dtype: object
# index              162
# location    Dallas, TX
# Lat            32.7767
# Lon            -96.797
# Name: 162, dtype: object
# index                163
# location    Woodmore, MD
# Lat              38.9212
# Lon              -76.803
# Name: 163, dtype: object
# index                      165
# location    Eastern Washington
# Lat                     47.491
# Lon                   -117.586
# Name: 165, dtype: object
# index                  166
# location    Cavern Country
# Lat                29.6924
# Lon               -98.3427
# Name: 166, dtype: object
# index                         167
# location    Sullivan's Island, SC
# Lat                       32.7632
# Lon                      -79.8368
# Name: 167, dtype: object
# index               168
# location    Chicago, IL
# Lat             41.8781
# Lon            -87.6298
# Name: 168, dtype: object
# index                                             169
# location    Springfield MO, dreams it could MI again.
# Lat                                            37.209
# Lon                                          -93.2923
# Name: 169, dtype: object
# index                     170
# location    Xavier University
# Lat                   29.9641
# Lon                  -90.1076
# Name: 170, dtype: object
# index                              172
# location    Exchange Road Haveli Lakha
# Lat                            30.4458
# Lon                            73.7006
# Name: 172, dtype: object
# index                              173
# location    Hazratganj, Lucknow, India
# Lat                            26.8542
# Lon                            80.9448
# Name: 173, dtype: object
# index                 174
# location    San Diego, CA
# Lat               32.7157
# Lon              -117.161
# Name: 174, dtype: object
# index             175
# location    minnesota
# Lat           46.7296
# Lon          -94.6859
# Name: 175, dtype: object
# index                     176
# location    Alabama, Biotch!
# Lat                   32.3182
# Lon                  -86.9023
# Name: 176, dtype: object
# index                                177
# location    Montreal • New York • London
# Lat                              45.5061
# Lon                             -73.5536
# Name: 177, dtype: object
# index               178
# location    Raleigh, NC
# Lat             35.7796
# Lon            -78.6382
# Name: 178, dtype: object
# index                     179
# location    Orange County, CA
# Lat                   33.7175
# Lon                  -117.831
# Name: 179, dtype: object
# index              180
# location    Denver, CO
# Lat            39.7392
# Lon            -104.99
# Name: 180, dtype: object
# index               181
# location    Houston, TX
# Lat             29.7604
# Lon            -95.3698
# Name: 181, dtype: object
# index                  182
# location    Wisconsin, USA
# Lat                43.7844
# Lon               -88.7879
# Name: 182, dtype: object
# index                   183
# location    Los Angeles, CA
# Lat                 34.0522
# Lon                -118.244
# Name: 183, dtype: object
# index                  185
# location    Liberty Avenue
# Lat                40.6838
# Lon               -73.8335
# Name: 185, dtype: object
# index           186
# location    ARIZONA
# Lat         34.0489
# Lon        -111.094
# Name: 186, dtype: object
# index                      187
# location    Pondicherry, India
# Lat                    11.9416
# Lon                    79.8083
# Name: 187, dtype: object
# index                            188
# location    British Columbia, Canada
# Lat                          53.7267
# Lon                         -127.648
# Name: 188, dtype: object
# index                            189
# location    Scotland, United Kingdom
# Lat                          56.4907
# Lon                         -4.20265
# Name: 189, dtype: object
# index                     190
# location    Sydney, Australia
# Lat                  -33.8688
# Lon                   151.209
# Name: 190, dtype: object
# index                191
# location    Planet Earth
# Lat              38.2537
# Lon             -78.4587
# Name: 191, dtype: object
# index                            192
# location    St Kew Highway, Cornwall
# Lat                          50.5468
# Lon                         -4.78134
# Name: 192, dtype: object
# index                193
# location    San Jose, CA
# Lat              37.3382
# Lon             -121.886
# Name: 193, dtype: object
# index                                194
# location    18 Lalbazar St. Kolkata-1,WB
# Lat                              22.5726
# Lon                              88.3524
# Name: 194, dtype: object
# index                    195
# location    Faridabad, India
# Lat                  28.4089
# Lon                  77.3178
# Name: 195, dtype: object
# index               196
# location    Fredericton
# Lat             45.9636
# Lon            -66.6431
# Name: 196, dtype: object
# index                  197
# location    Bellflower, CA
# Lat                33.8817
# Lon               -118.117
# Name: 197, dtype: object
# index                     198
# location    Helsinki, Finland
# Lat                   60.1699
# Lon                   24.9384
# Name: 198, dtype: object
# index                       199
# location    Deerfield Beach, FL
# Lat                     26.3184
# Lon                    -80.0998
# Name: 199, dtype: object
# index                   200
# location    South Haven, MI
# Lat                 42.4031
# Lon                -86.2736
# Name: 200, dtype: object
# index           201
# location    Manila
# Lat         14.5995
# Lon         120.984
# Name: 201, dtype: object
# index                    202
# location    White Plains, NY
# Lat                   41.034
# Lon                 -73.7629
# Name: 202, dtype: object
# index                203
# location    Al Ain, UAE
# Lat              24.1302
# Lon              55.8023
# Name: 203, dtype: object
# index                  204
# location    Bridgeport, WV
# Lat                39.2865
# Lon               -80.2562
# Name: 204, dtype: object
# index           205
# location     USA/TN
# Lat         35.5175
# Lon        -86.5804
# Name: 205, dtype: object
# index                  206
# location    Miami, Florida
# Lat                25.7617
# Lon               -80.1918
# Name: 206, dtype: object
# index                   207
# location    Phenix City, AL
# Lat                  32.471
# Lon                -85.0008
# Name: 207, dtype: object
# index                     208
# location    Lacey, Washington
# Lat                   47.0359
# Lon                  -122.823
# Name: 208, dtype: object
# index                    209
# location    Seattle, WA, USA
# Lat                  47.6062
# Lon                 -122.332
# Name: 209, dtype: object
# index                                  210
# location    Blue in red state turning blue
# Lat                                37.0902
# Lon                               -95.7129
# Name: 210, dtype: object
# index                   211
# location    Owerri, Nigeria
# Lat                 5.48906
# Lon                 7.01759
# Name: 211, dtype: object
# index                                  212
# location    244 E. 93rd St. - 212-860-1950
# Lat                                40.7824
# Lon                               -73.9491
# Name: 212, dtype: object
# index               213
# location    Orlando, FL
# Lat             28.5383
# Lon            -81.3792
# Name: 213, dtype: object
# index                           214
# location    Sudbury Ontario, Canada
# Lat                         46.4917
# Lon                         -80.993
# Name: 214, dtype: object
# index                   215
# location    Duke University
# Lat                 36.0014
# Lon                -78.9382
# Name: 215, dtype: object
# index             216
# location    Bronx, NY
# Lat           40.8448
# Lon          -73.8648
# Name: 216, dtype: object
# index                   217
# location    Berlin, Germany
# Lat                   52.52
# Lon                  13.405
# Name: 217, dtype: object
# index               218
# location    Gotham City
# Lat             41.8839
# Lon            -87.6317
# Name: 218, dtype: object
# index                  219
# location    United Kingdom
# Lat                55.3781
# Lon               -3.43597
# Name: 219, dtype: object
# index                       221
# location    Haagse Bloemenbuurt
# Lat                     52.0759
# Lon                     4.26001
# Name: 221, dtype: object
# index                  222
# location    MoCo, Maryland
# Lat                39.1547
# Lon               -77.2405
# Name: 222, dtype: object
# index                      223
# location    New York, New York
# Lat                    40.7128
# Lon                    -74.006
# Name: 223, dtype: object
# index                 224
# location    South Florida
# Lat               27.6648
# Lon              -81.5158
# Name: 224, dtype: object
# index                  225
# location    Philly suburbs
# Lat                39.9541
# Lon               -75.1669
# Name: 225, dtype: object
# index                   226
# location    Rajkot, Gujarat
# Lat                 22.3039
# Lon                 70.8022
# Name: 226, dtype: object
# index             227
# location    London UK
# Lat           51.5074
# Lon         -0.127758
# Name: 227, dtype: object
# index                    228
# location    East Olympia, WA
# Lat                  46.9676
# Lon                 -122.836
# Name: 228, dtype: object
# index             229
# location    New York
# Lat           40.7128
# Lon           -74.006
# Name: 229, dtype: object
# index                     230
# location    Pacific Northwest
# Lat                   41.8797
# Lon                  -87.6356
# Name: 230, dtype: object
# index                   231
# location    Tucson, Arizona
# Lat                 32.2226
# Lon                -110.975
# Name: 231, dtype: object
# index                        232
# location    Argyll, Scotland, UK
# Lat                      56.4006
# Lon                     -5.48075
# Name: 232, dtype: object
# index              233
# location    Tucson, AZ
# Lat            32.2226
# Lon           -110.975
# Name: 233, dtype: object
# index                                235
# location    #StGeorge~#StatenIsland~#NYC
# Lat                              40.6427
# Lon                             -74.0799
# Name: 235, dtype: object
# index            236
# location    Oklahoma
# Lat          35.4676
# Lon         -97.5164
# Name: 236, dtype: object
# index                            237
# location    not too far from Normal
# Lat                           37.684
# Lon                         -97.3167
# Name: 237, dtype: object
# index                    238
# location    London and Dubai
# Lat                  51.4989
# Lon                -0.134961
# Name: 238, dtype: object
# index                    239
# location    Washington, D.C.
# Lat                  38.9072
# Lon                 -77.0369
# Name: 239, dtype: object
# index           240
# location         NY
# Lat         40.7128
# Lon         -74.006
# Name: 240, dtype: object
# index                  241
# location    Des Moines, IA
# Lat                41.5868
# Lon                -93.625
# Name: 241, dtype: object
# index                        242
# location    Southampton, England
# Lat                      50.9097
# Lon                     -1.40435
# Name: 242, dtype: object
# index                243
# location    Bend, Oregon
# Lat              44.0582
# Lon             -121.315
# Name: 243, dtype: object
# index              246
# location    New Mexico
# Lat            34.5199
# Lon            -105.87
# Name: 246, dtype: object
# index           247
# location    Bermuda
# Lat         32.3078
# Lon        -64.7505
# Name: 247, dtype: object
# index                 248
# location    Rajkot, India
# Lat               22.3039
# Lon               70.8022
# Name: 248, dtype: object
# index                249
# location    Cerritos, CA
# Lat              33.8583
# Lon             -118.065
# Name: 249, dtype: object
# index                250
# location    Columbia, SC
# Lat              34.0007
# Lon             -81.0348
# Name: 250, dtype: object
# index                251
# location    Gillette, WY
# Lat              44.2911
# Lon             -105.502
# Name: 251, dtype: object
# index                 252
# location    Maryland, USA
# Lat               39.0458
# Lon              -76.6413
# Name: 252, dtype: object
# index                       253
# location    Islamabad, Pakistan
# Lat                     33.6844
# Lon                     73.0479
# Name: 253, dtype: object
# index           254
# location     SLC UT
# Lat         40.7608
# Lon        -111.891
# Name: 254, dtype: object
# index           255
# location      Japan
# Lat         36.2048
# Lon         138.253
# Name: 255, dtype: object
# index           256
# location    Nairobi
# Lat        -1.29207
# Lon         36.8219
# Name: 256, dtype: object
# index               257
# location    Detroit, MI
# Lat             42.3314
# Lon            -83.0458
# Name: 257, dtype: object
# index                    258
# location    Gurgaon, Haryana
# Lat                  28.4595
# Lon                  77.0266
# Name: 258, dtype: object
# index            262
# location      London
# Lat          51.5074
# Lon        -0.127758
# Name: 262, dtype: object
# index                      263
# location    Odo-Ijoka , Akure.
# Lat                     7.2649
# Lon                    5.19346
# Name: 263, dtype: object
# index                      264
# location    West Bengal, India
# Lat                    22.9868
# Lon                     87.855
# Name: 264, dtype: object
# index                265
# location    Berkeley, CA
# Lat              37.8715
# Lon             -122.273
# Name: 265, dtype: object
# index              267
# location    Colchester
# Lat            51.8959
# Lon           0.891874
# Name: 267, dtype: object
# index              268
# location    Queens, NY
# Lat            40.7282
# Lon           -73.7949
# Name: 268, dtype: object
# index                     269
# location    Chandigarh, India
# Lat                   30.7333
# Lon                   76.7794
# Name: 269, dtype: object
# index                   270
# location    Schenectady, NY
# Lat                 42.8142
# Lon                -73.9396
# Name: 270, dtype: object
# index                 271
# location    Michigan, USA
# Lat               44.3148
# Lon              -85.6024
# Name: 271, dtype: object
# index                 273
# location    Las Vegas, NV
# Lat               36.1699
# Lon               -115.14
# Name: 273, dtype: object
# index                 274
# location    Nagpur, India
# Lat               21.1458
# Lon               79.0882
# Name: 274, dtype: object
# index                 275
# location    Nashville, TN
# Lat               36.1627
# Lon              -86.7816
# Name: 275, dtype: object
# index                      276
# location    Fredericksburg, VA
# Lat                    38.3032
# Lon                   -77.4605
# Name: 276, dtype: object
# index                 277
# location    Nebraska, USA
# Lat               41.4925
# Lon              -99.9018
# Name: 277, dtype: object
# index           278
# location      Earth
# Lat         37.2321
# Lon        -95.7243
# Name: 278, dtype: object
# index                  280
# location    Genoa, Liguria
# Lat                44.4056
# Lon                8.94626
# Name: 280, dtype: object
# index                                  281
# location    Yorkshire and The Humber, Engl
# Lat                                53.9062
# Lon                               -1.03336
# Name: 281, dtype: object
# index           282
# location       Cork
# Lat         32.8072
# Lon        -96.7964
# Name: 282, dtype: object
# index                283
# location    Pennsylvania
# Lat              41.2033
# Lon             -77.1945
# Name: 283, dtype: object
# index                    284
# location    Honolulu, Hawaii
# Lat                  21.3069
# Lon                 -157.858
# Name: 284, dtype: object
# index                    285
# location    Northern NJ  USA
# Lat                  40.9263
# Lon                  -74.077
# Name: 285, dtype: object
# index                 286
# location    Papillion, NE
# Lat               41.1544
# Lon              -96.0422
# Name: 286, dtype: object
# index                     287
# location    San Francisco, CA
# Lat                   37.7749
# Lon                  -122.419
# Name: 287, dtype: object
# index                  288
# location    Sutton, London
# Lat                51.3614
# Lon              -0.193961
# Name: 288, dtype: object
# index                      289
# location    Los Ángeles, Chile
# Lat                   -37.4629
# Lon                   -72.3612
# Name: 289, dtype: object
# index                                 290
# location    London, Glasgow, Los Angeles
# Lat                               51.5074
# Lon                             -0.127758
# Name: 290, dtype: object
# index           291
# location    Ontario
# Lat         51.2538
# Lon        -85.3232
# Name: 291, dtype: object
# index                 292
# location    Missouri, USA
# Lat               37.9643
# Lon              -91.8318
# Name: 292, dtype: object
# index                             293
# location    Wexford & Dublin, Ireland
# Lat                            53.337
# Lon                          -6.26563
# Name: 293, dtype: object
# index               294
# location    Atlanta, GA
# Lat              33.749
# Lon             -84.388
# Name: 294, dtype: object
# index                  295
# location    Sacramento, CA
# Lat                38.5816
# Lon               -121.494
# Name: 295, dtype: object
# index                     297
# location    Pennsylvania, USA
# Lat                   41.2033
# Lon                  -77.1945
# Name: 297, dtype: object
# index                       298
# location    Makwanpur- Heatauda
# Lat                     27.4368
# Lon                     85.0026
# Name: 298, dtype: object
# index                            299
# location    columbia, south carolina
# Lat                          34.0007
# Lon                         -81.0348
# Name: 299, dtype: object
# index             300
# location    Colorado
# Lat           39.5501
# Lon          -105.782
# Name: 300, dtype: object
# index               302
# location    Buffalo, NY
# Lat             42.8864
# Lon            -78.8784
# Name: 302, dtype: object
# index           303
# location     #NY27
# Lat          43.055
# Lon        -78.4752
# Name: 303, dtype: object
# index                 304
# location    Tampa Bay, FL
# Lat               27.7634
# Lon              -82.5437
# Name: 304, dtype: object
# index            305
# location    Thailand
# Lat            15.87
# Lon          100.993
# Name: 305, dtype: object
# index           306
# location      Asean
# Lat         34.0479
# Lon          100.62
# Name: 306, dtype: object
# index                     307
# location    Pattaya, Thailand
# Lat                   12.9236
# Lon                   100.882
# Name: 307, dtype: object
# index           308
# location    Glasgow
# Lat         55.8642
# Lon        -4.25181
# Name: 308, dtype: object
# index                309
# location    Brooklyn, NY
# Lat              40.6782
# Lon             -73.9442
# Name: 309, dtype: object
# index                          310
# location    Sherwood Park, Alberta
# Lat                        53.5412
# Lon                       -113.296
# Name: 310, dtype: object
# index                        312
# location    Heartland of America
# Lat                      44.8579
# Lon                      -93.593
# Name: 312, dtype: object
# index                  313
# location    Alexandria, VA
# Lat                38.8048
# Lon               -77.0469
# Name: 313, dtype: object
# index                 314
# location    Oklahoma, USA
# Lat               35.0078
# Lon              -97.0929
# Name: 314, dtype: object
# index                    315
# location    Chicago, IL, USA
# Lat                  41.8781
# Lon                 -87.6298
# Name: 315, dtype: object
# index                      316
# location    Massachusetts, USA
# Lat                    42.4072
# Lon                   -71.3824
# Name: 316, dtype: object
# index              317
# location    Madison WI
# Lat            43.0731
# Lon           -89.4012
# Name: 317, dtype: object
# index              318
# location    Austin, TX
# Lat            30.2672
# Lon           -97.7431
# Name: 318, dtype: object
# index                                 319
# location    Mahikeng, North West Province
# Lat                               -25.856
# Lon                               25.6403
# Name: 319, dtype: object
# index                320
# location    Honolulu, HI
# Lat              21.3069
# Lon             -157.858
# Name: 320, dtype: object
# index           321
# location    Germany
# Lat         51.1657
# Lon         10.4515
# Name: 321, dtype: object
# index                322
# location    Portland, OR
# Lat              45.5051
# Lon             -122.675
# Name: 322, dtype: object
# index              323
# location    Nunya, biz
# Lat            41.7507
# Lon           -83.6264
# Name: 323, dtype: object
# index           324
# location      India
# Lat         20.5937
# Lon         78.9629
# Name: 324, dtype: object
# index             325
# location    Matlosana
# Lat          -26.8618
# Lon           26.5138
# Name: 325, dtype: object
# index                     326
# location    Brighton, England
# Lat                   50.8225
# Lon                 -0.137163
# Name: 326, dtype: object
# index               327
# location    Ipswich, UK
# Lat             52.0567
# Lon             1.14822
# Name: 327, dtype: object
# index                     328
# location    Texas and Ireland
# Lat                   52.6512
# Lon                  -7.25264
# Name: 328, dtype: object
# index                         329
# location    Travelling, Australia
# Lat                       29.5166
# Lon                      -98.4969
# Name: 329, dtype: object
# index           330
# location    Halifax
# Lat         44.6476
# Lon        -63.5728
# Name: 330, dtype: object
# index                          331
# location    University of Stirling
# Lat                        56.1454
# Lon                       -3.92057
# Name: 331, dtype: object
# index                          332
# location    Randburg, South Africa
# Lat                       -26.1438
# Lon                        27.9952
# Name: 332, dtype: object
# index           333
# location       kasi
# Lat         42.0253
# Lon        -93.6162
# Name: 333, dtype: object
# index                   334
# location    New Jersey, USA
# Lat                 40.0583
# Lon                -74.4057
# Name: 334, dtype: object
# index                                 335
# location    1622 Sackville Dr, MSackville
# Lat                               44.7944
# Lon                               -63.723
# Name: 335, dtype: object
# index                            336
# location    South Africa ,Mpumalanga
# Lat                         -25.5653
# Lon                          30.5279
# Name: 336, dtype: object
# index                337
# location    Newyork city
# Lat              40.7128
# Lon              -74.006
# Name: 337, dtype: object
# index                 338
# location    Austin, Texas
# Lat               30.2672
# Lon              -97.7431
# Name: 338, dtype: object
# index            339
# location    Lena, IL
# Lat          42.3795
# Lon         -89.8223
# Name: 339, dtype: object
# index             341
# location    Wisconsin
# Lat           43.7844
# Lon          -88.7879
# Name: 341, dtype: object
# index                      342
# location    Virginia Beach, VA
# Lat                    36.8529
# Lon                    -75.978
# Name: 342, dtype: object
# index                           343
# location    Ottawa, Ontario, Canada
# Lat                         45.4215
# Lon                        -75.6972
# Name: 343, dtype: object
# index                      344
# location    Newtown Square, PA
# Lat                    39.9869
# Lon                   -75.4007
# Name: 344, dtype: object
# index              346
# location     New York
# Lat            40.7128
# Lon            -74.006
# Name: 346, dtype: object
# index                  347
# location    Cincinnati, OH
# Lat                39.1031
# Lon                -84.512
# Name: 347, dtype: object
# index               348
# location    GTA Ontario
# Lat             44.0384
# Lon               -79.2
# Name: 348, dtype: object
# index                      349
# location    49.497753,7.593849
# Lat                    49.4978
# Lon                    7.59397
# Name: 349, dtype: object
# index                    350
# location    www.mp-magic.com
# Lat                  22.9734
# Lon                  78.6569
# Name: 350, dtype: object
# index                             351
# location    Lancing & Basse Normandie
# Lat                           50.8282
# Lon                         -0.328092
# Name: 351, dtype: object
# index           352
# location    Florida
# Lat         27.6648
# Lon        -81.5158
# Name: 352, dtype: object
# index           353
# location         UK
# Lat         55.3781
# Lon        -3.43597
# Name: 353, dtype: object
# index                           355
# location    The Island of Manhattan
# Lat                         40.6895
# Lon                        -74.0168
# Name: 355, dtype: object
# index            356
# location    Wordwide
# Lat          40.0421
# Lon         -76.3888
# Name: 356, dtype: object
# index                  357
# location    The Resistance
# Lat                 33.814
# Lon               -117.923
# Name: 357, dtype: object
# index                       358
# location    College Station, TX
# Lat                      30.628
# Lon                    -96.3344
# Name: 358, dtype: object
# index                   359
# location    Hamilton Canada
# Lat                 43.2557
# Lon                -79.8711
# Name: 359, dtype: object
# index                   361
# location    Ontario, Canada
# Lat                 51.2538
# Lon                -85.3232
# Name: 361, dtype: object
# index                    362
# location    Coney Island, NY
# Lat                  40.5755
# Lon                 -73.9707
# Name: 362, dtype: object
# index              363
# location    California
# Lat            36.7783
# Lon           -119.418
# Name: 363, dtype: object
# index              364
# location    Custer, SD
# Lat            43.7667
# Lon           -103.599
# Name: 364, dtype: object
# index                   365
# location    Phoenix, AZ 🌵🌵🌵
# Lat                 33.6025
# Lon                -112.033
# Name: 365, dtype: object
# index                    366
# location    Green Valley, AZ
# Lat                  31.8543
# Lon                 -110.994
# Name: 366, dtype: object
# index                       367
# location    Zurich, Switzerland
# Lat                     47.3769
# Lon                     8.54169
# Name: 367, dtype: object
# index           369
# location    Midwest
# Lat          36.132
# Lon        -96.0109
# Name: 369, dtype: object
# index           370
# location         KS
# Lat         39.0119
# Lon        -98.4842
# Name: 370, dtype: object
# index                     371
# location    Moreno Valley, CA
# Lat                   33.9425
# Lon                   -117.23
# Name: 371, dtype: object
# index                      372
# location    House of Burlesque
# Lat                    41.8787
# Lon                    -71.386
# Name: 372, dtype: object
# index              373
# location    Kirriemuir
# Lat            56.6751
# Lon            -3.0035
# Name: 373, dtype: object
# index           375
# location       iran
# Lat         32.4279
# Lon          53.688
# Name: 375, dtype: object
# index                                  376
# location    Rio de Janeiro, Rio de Janeiro
# Lat                               -22.9068
# Lon                               -43.1729
# Name: 376, dtype: object
# index                 377
# location    Jaipur, India
# Lat               26.9124
# Lon               75.7873
# Name: 377, dtype: object
# index                           378
# location    Rothbury Northumberland
# Lat                         55.3105
# Lon                        -1.90955
# Name: 378, dtype: object
# index               379
# location    Tamworth uk
# Lat             52.6336
# Lon            -1.69103
# Name: 379, dtype: object
# index                  380
# location    South Carolina
# Lat                33.8361
# Lon               -81.1637
# Name: 380, dtype: object
# index                       382
# location    northern California
# Lat                     38.8375
# Lon                    -120.896
# Name: 382, dtype: object
# index                             384
# location    Alsbach-Hähnlein, Germany
# Lat                           49.7366
# Lon                           8.58523
# Name: 384, dtype: object
# index                            385
# location    sean | they/them | white
# Lat                          38.8977
# Lon                         -77.0365
# Name: 385, dtype: object
# ...
# Name: 14274, dtype: object
# index                     14275
# location    Kreuztal/Siegerland
# Lat                     50.9694
# Lon                     7.99236
# Name: 14275, dtype: object
# index              14277
# location    ringwood, uk
# Lat              50.8449
# Lon             -1.78882
# Name: 14277, dtype: object
# index                          14279
# location    Warsaw, London, New York
# Lat                          51.5074
# Lon                        -0.127758
# Name: 14279, dtype: object
# index                     14280
# location    Canberra, Australia
# Lat                    -35.2809
# Lon                      149.13
# Name: 14280, dtype: object
# index                         14281
# location    outer north west London
# Lat                         51.5074
# Lon                       -0.127758
# Name: 14281, dtype: object
# index                14283
# location    Delph, England
# Lat                53.5675
# Lon               -2.02108
# Name: 14283, dtype: object
# index         14284
# location    Chester
# Lat         37.9137
# Lon        -89.8221
# Name: 14284, dtype: object
# index                   14285
# location    Alabama boy in PA
# Lat                   32.3182
# Lon                  -86.9023
# Name: 14285, dtype: object
# index                  14287
# location    Eastern seaboard
# Lat                  37.0902
# Lon                 -95.7129
# Name: 14287, dtype: object
# index                 14288
# location    Buffalo/Toronto
# Lat                  42.882
# Lon                -78.8799
# Name: 14288, dtype: object
# index                  14289
# location    Hiroshima, Japan
# Lat                  34.3853
# Lon                  132.455
# Name: 14289, dtype: object
# index             14292
# location    Jackson, GA
# Lat             33.2946
# Lon             -83.966
# Name: 14292, dtype: object
# index             14293
# location    Winter Park
# Lat             39.8917
# Lon            -105.763
# Name: 14293, dtype: object
# index           14295
# location    Valhalla
# Lat           41.0748
# Lon          -73.7751
# Name: 14295, dtype: object
# index           14297
# location    Utica, NY
# Lat           43.1009
# Lon          -75.2327
# Name: 14297, dtype: object
# index                                    14298
# location    Federal Capital Territory, Nigeria
# Lat                                    8.89407
# Lon                                    7.18604
# Name: 14298, dtype: object
# index                 14299
# location    Irish in France
# Lat                 34.1011
# Lon                -83.8185
# Name: 14299, dtype: object
# index              14300
# location    Nappanee, IN
# Lat              41.4428
# Lon             -86.0014
# Name: 14300, dtype: object
# index                      14301
# location    Vacationland (Maine)
# Lat                      44.1316
# Lon                     -70.6769
# Name: 14301, dtype: object
# index                  14302
# location    Cologne, Germany
# Lat                  50.9375
# Lon                  6.96028
# Name: 14302, dtype: object
# index            14303
# location    The Garden
# Lat            36.0959
# Lon           -95.9184
# Name: 14303, dtype: object
# index                14304
# location    Kampala-Uganda
# Lat               0.347596
# Lon                32.5825
# Name: 14304, dtype: object
# index                        14305
# location    Craigieburn, Melbourne
# Lat                        -37.594
# Lon                        144.934
# Name: 14305, dtype: object
# index                             14307
# location    Los Angeles, California USA
# Lat                             34.0522
# Lon                            -118.244
# Name: 14307, dtype: object
# index                  14308
# location    Dublin, Ireland.
# Lat                  53.3498
# Lon                 -6.26031
# Name: 14308, dtype: object
# index                                14309
# location    Vero Beach/Saugatuck/AnnArbor
# Lat                                27.6386
# Lon                               -80.3973
# Name: 14309, dtype: object
# index                14310
# location    Caughdenoy, NY
# Lat                43.2867
# Lon                -76.146
# Name: 14310, dtype: object
# index           14311
# location    West Aust
# Lat          -27.6728
# Lon           121.628
# Name: 14311, dtype: object
# index               14312
# location    Liverpool, NY
# Lat               43.1065
# Lon              -76.2177
# Name: 14312, dtype: object
# index                          14313
# location    Miami, Milan, Viareggio
# Lat                          25.7617
# Lon                         -80.1918
# Name: 14313, dtype: object
# index                  14315
# location    Pawtuxet Village
# Lat                  41.7638
# Lon                 -71.3905
# Name: 14315, dtype: object
# index                         14316
# location    Southend-on-Sea, Essex
# Lat                         51.5459
# Lon                        0.707712
# Name: 14316, dtype: object
# index                          14317
# location    Devildom | Survey Corps
# Lat                           36.166
# Lon                         -86.7835
# Name: 14317, dtype: object
# index                14318
# location    Washington, MO
# Lat                38.5581
# Lon               -91.0121
# Name: 14318, dtype: object
# index                  14319
# location    Belgrade, Serbia
# Lat                  44.7866
# Lon                  20.4489
# Name: 14319, dtype: object
# index         14320
# location      ISLAM
# Lat         36.0959
# Lon        -95.9116
# Name: 14320, dtype: object
# index                     14321
# location    Niebüll, Südtondern
# Lat                     54.7874
# Lon                     8.83084
# Name: 14321, dtype: object
# index                           14322
# location    Heian-Jingu, Kyoto, Japão
# Lat                            35.016
# Lon                           135.782
# Name: 14322, dtype: object
# index                           14323
# location    Toronto 🇨🇦 / Melbourne 🇦🇺
# Lat                           43.6532
# Lon                          -79.3832
# Name: 14323, dtype: object
# index             14324
# location    Aldona, Goa
# Lat             15.5933
# Lon             73.8713
# Name: 14324, dtype: object
# index                      14325
# location    West Sussex, England
# Lat                       50.928
# Lon                    -0.461707
# Name: 14325, dtype: object
# index         14326
# location      #FL18
# Lat          27.124
# Lon        -80.3659
# Name: 14326, dtype: object
# index                    14327
# location    Bradenton, Florida
# Lat                    27.4989
# Lon                   -82.5748
# Name: 14327, dtype: object
# index                  14328
# location    Smokey Point, WA
# Lat                  48.1676
# Lon                 -122.192
# Name: 14328, dtype: object
# index                   14329
# location    Kilkenny, Ireland
# Lat                   52.6541
# Lon                  -7.24479
# Name: 14329, dtype: object
# index                   14330
# location    Stafford, England
# Lat                   52.8067
# Lon                  -2.12066
# Name: 14330, dtype: object
# index          14331
# location    Silvassa
# Lat          20.2753
# Lon          73.0073
# Name: 14331, dtype: object
# index                 14333
# location    Africa, Uganda
# Lat                 1.37333
# Lon                 32.2903
# Name: 14333, dtype: object
# index            14335
# location    Storrs, CT
# Lat            41.8084
# Lon           -72.2495
# Name: 14335, dtype: object
# index                                                   14336
# location    280 Henry Street NY, NY 10002 &  1427 Broadway...
# Lat                                                   40.6884
# Lon                                                  -73.9199
# Name: 14336, dtype: object
# index                  14337
# location    Los Angeles area
# Lat                  34.0522
# Lon                 -118.244
# Name: 14337, dtype: object
# index                          14338
# location    Chicago, IL & Denver, CO
# Lat                          39.7533
# Lon                         -104.994
# Name: 14338, dtype: object
# index                      14339
# location    On top of the world
# Lat                      29.0811
# Lon                     -82.2595
# Name: 14339, dtype: object
# index                    14340
# location    Farmers Branch, TX
# Lat                    32.9265
# Lon                   -96.8961
# Name: 14340, dtype: object
# index              14343
# location    Havaiji, USA
# Lat              19.8968
# Lon             -155.583
# Name: 14343, dtype: object
# index                        14345
# location    The Blue United States
# Lat                        37.0902
# Lon                       -95.7129
# Name: 14345, dtype: object
# index                  14347
# location    Washington Metro
# Lat                  38.9245
# Lon                 -77.0524
# Name: 14347, dtype: object
# index                              14348
# location    SAVE THE WORLD USA..NO TRUMP
# Lat                              40.8947
# Lon                             -73.9426
# Name: 14348, dtype: object
# index              14349
# location    Umatilla, FL
# Lat              28.9294
# Lon             -81.6656
# Name: 14349, dtype: object
# index                        14350
# location    New Westminster, B. C.
# Lat                        49.2057
# Lon                       -122.911
# Name: 14350, dtype: object
# index                   14352
# location    Boscombe, England
# Lat                   50.7236
# Lon                  -1.84846
# Name: 14352, dtype: object
# index                  14353
# location    Berlin, Germany
# Lat                    52.52
# Lon                   13.405
# Name: 14353, dtype: object
# index           14357
# location    Olney, MD
# Lat           39.1532
# Lon          -77.0669
# Name: 14357, dtype: object
# index                      14358
# location    Talavera de la Reina
# Lat                      39.9629
# Lon                     -4.83045
# Name: 14358, dtype: object
# index               14360
# location    USA, Maryland
# Lat               39.0458
# Lon              -76.6413
# Name: 14360, dtype: object
# index          14363
# location    betanzos
# Lat          43.2784
# Lon         -8.21312
# Name: 14363, dtype: object
# index             14364
# location    Thirst City
# Lat             40.7414
# Lon            -111.889
# Name: 14364, dtype: object
# index             14366
# location    Hawkins, IN
# Lat             36.7931
# Lon            -91.8952
# Name: 14366, dtype: object
# index                   14368
# location    Mississippi Delta
# Lat                   33.4442
# Lon                  -90.5038
# Name: 14368, dtype: object
# index           14372
# location    Nashvegas
# Lat           38.9518
# Lon          -92.3267
# Name: 14372, dtype: object
# index                      14373
# location    Zhongshan, Guangdong
# Lat                      22.5176
# Lon                      113.393
# Name: 14373, dtype: object
# index                              14375
# location    Close to the edge of Sydney.
# Lat                             -33.8708
# Lon                              151.205
# Name: 14375, dtype: object
# index            14376
# location    Over there
# Lat            39.0809
# Lon           -94.5864
# Name: 14376, dtype: object
# index             14377
# location    大阪・泉南りんくう公園
# Lat             34.4124
# Lon             135.295
# Name: 14377, dtype: object
# index               14378
# location    Osaka - Japan
# Lat               34.6937
# Lon               135.502
# Name: 14378, dtype: object
# index             14379
# location    Chester, UK
# Lat             53.1934
# Lon            -2.89308
# Name: 14379, dtype: object
# index                 14380
# location    Milan, Lombardy
# Lat                 45.4642
# Lon                 9.18998
# Name: 14380, dtype: object
# index              14381
# location    THE UNIVERSE
# Lat              36.1569
# Lon             -95.9915
# Name: 14381, dtype: object
# index                          14385
# location    Canoga Park, Los Angeles
# Lat                          34.2083
# Lon                         -118.606
# Name: 14385, dtype: object
# index              14386
# location    Mainz/London
# Lat              50.0003
# Lon              8.13159
# Name: 14386, dtype: object
# index           14387
# location    Azusa, CA
# Lat           34.1336
# Lon          -117.908
# Name: 14387, dtype: object
# index         14389
# location     Ladakh
# Lat         38.8935
# Lon        -77.0304
# Name: 14389, dtype: object
# index                        14392
# location    Cáceres del Perú, Peru
# Lat                       -8.95115
# Lon                       -78.0652
# Name: 14392, dtype: object
# index                                14393
# location    High Desert, Northern NV - USA
# Lat                                39.5215
# Lon                                -119.72
# Name: 14393, dtype: object
# index                      14395
# location    on top of the world
# Lat                      29.0811
# Lon                     -82.2595
# Name: 14395, dtype: object
# index                         14396
# location    Los angeles, California
# Lat                         34.0522
# Lon                        -118.244
# Name: 14396, dtype: object
# index                 14397
# location    Croatia, Rijeka
# Lat                 45.3271
# Lon                 14.4422
# Name: 14397, dtype: object
# index            14400
# location    Bronx, NY
# Lat            40.8448
# Lon           -73.8648
# Name: 14400, dtype: object
# index           14404
# location    STL / NYC
# Lat           40.7236
# Lon          -73.9981
# Name: 14404, dtype: object
# index                         14405
# location    Greater Toronto, Canada
# Lat                         44.0384
# Lon                           -79.2
# Name: 14405, dtype: object
# index                 14408
# location    Roubaix, France
# Lat                 50.6927
# Lon                 3.17785
# Name: 14408, dtype: object
# index            14409
# location    Norwottuck
# Lat            42.3056
# Lon             -72.51
# Name: 14409, dtype: object
# index                            14410
# location    Florida, USA-Cuba-American
# Lat                            27.6648
# Lon                           -81.5158
# Name: 14410, dtype: object
# index                     14411
# location    Houston, Texas, USA
# Lat                     29.7604
# Lon                    -95.3698
# Name: 14411, dtype: object
# index                14412
# location    Chinon, France
# Lat                47.1673
# Lon               0.240385
# Name: 14412, dtype: object
# index                    14413
# location    NYC - Proudly made
# Lat                    40.7128
# Lon                    -74.006
# Name: 14413, dtype: object
# index                        14414
# location    Alaska 🇺🇲 / Finland 🇫🇮
# Lat                        64.2008
# Lon                       -149.494
# Name: 14414, dtype: object
# index                14415
# location    Reidsville, NC
# Lat                36.3549
# Lon               -79.6645
# Name: 14415, dtype: object
# index              14416
# location    Chicopee, MA
# Lat              42.1487
# Lon             -72.6079
# Name: 14416, dtype: object
# index                               14417
# location    Windermere,FL & the Caribbean
# Lat                               28.5152
# Lon                              -81.5431
# Name: 14417, dtype: object
# index               14418
# location    Dahlonega, GA
# Lat               34.5261
# Lon              -83.9844
# Name: 14418, dtype: object
# index         14420
# location     MI-8th
# Lat         42.6298
# Lon        -84.0167
# Name: 14420, dtype: object
# index             14422
# location    Chicago. IL
# Lat             41.8781
# Lon            -87.6298
# Name: 14422, dtype: object
# index                         14424
# location    Polokwane, South Africa
# Lat                        -23.8962
# Lon                         29.4486
# Name: 14424, dtype: object
# index                14426
# location    Eastern Europe
# Lat                52.0055
# Lon                37.9587
# Name: 14426, dtype: object
# index               14427
# location    Mental asylum
# Lat               36.6592
# Lon              -95.1245
# Name: 14427, dtype: object
# index                             14428
# location    From the old North Philly!
# Lat                             40.0145
# Lon                            -75.1311
# Name: 14428, dtype: object
# index                          14429
# location    California, or wherever.
# Lat                          36.7783
# Lon                         -119.418
# Name: 14429, dtype: object
# index                          14430
# location    Kensington, Philadelphia
# Lat                          39.9934
# Lon                          -75.118
# Name: 14430, dtype: object

# %%
geocode_location.to_csv("location_promask.csv",encoding='utf-8-sig', index = False)

# %%
location_info = pd.read_csv('location_promask_usa.csv')

# %%
df.merge(location_info[['location','Lat','Lon','USA']], 
         left_on = "User Location", right_on = "location",
         how = 'left').to_csv('pro_mask_geocoded.csv',
                              encoding='utf-8-sig', index = False)

# %%
df_all = df.merge(location_info[['location','Lat','Lon','USA']], 
         left_on = "User Location", right_on = "location",
         how = 'left')

# %%
len(df_all['User Id'])
# Out:
# 48443

# %%
len(pd.unique(df_all['User Id']))
# Out:
# 39845

# %%
df_user = df_all.drop_duplicates(subset='User Id', keep="first")

# %%
len(df_user[~pd.isna(df_user['Lat'])])
# Out:
# 25145

# %%
df_user[['User Id','User Name','location','Lat','Lon','USA']].to_csv('pro_mask_user.csv',
                              encoding='utf-8-sig', index = False)
