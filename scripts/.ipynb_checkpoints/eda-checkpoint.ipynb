# %%
import os 
import glob 

import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## Directories

# %%
data_dir = "../data"

# %% [markdown]
# ## Read files

# %%
filename = "April_NoMask_Tweets.csv"


df = pd.read_csv(os.path.join(data_dir, "NoMask_Tweets_Version_2", filename))

# %%
df.shape

# %%
df.columns

# %%
df.columns

# %%
df_eng = df[df["Language"] == "en"]

# %%
df_eng.shape

# %% [markdown]
# ## BERT Features

# %%
import feature_extraction_via_BERTTweet

BERT_feature2D = feature_extraction_via_BERTTweet.get_features(df_eng, 0)

# %%
BERT_feature2D.shape

# %%
def wrt_single_file(filename, wrt_dir):
    df = pd.read_csv(filename)
    latent_val_df = feature_extraction_via_BERTTweet.get_features(df, 0)

    # write file to disk  
    latent_filename = filename.split("/")[-1]
    latent_val_df.to_csv(os.path.join(wrt_dir, latent_filename), index=False, header=True)

    return 0

# %%
filename = "April_NoMask_Tweets.csv"
wrt_dir = "../data/BERTTweet_Features"

wrt_single_file(os.path.join("../data/nomask_tweets_v2_eng", filename), wrt_dir)

# %%
filename = "August_NoMask_Tweets.csv"
wrt_dir = "../data/BERTTweet_Features"

wrt_single_file(os.path.join("../data/nomask_tweets_v2_eng", filename), wrt_dir)

# %% [markdown]
# ## VADER for Text Polarity Identity

# %%
import nltk

nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# sentiment_model = SentimentIntensityAnalyzer()

# a = 'This was a good movie.'
# x = sentiment_model.polarity_scores(a)


import nltk

nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer


def get_sentiment(df):
    sentiment_model = SentimentIntensityAnalyzer()
    df['sentimentDict'] = df['Tweet Text'].apply(lambda tweet: sentiment_model.polarity_scores(tweet))
    
    df['vader_neg']  = df['sentimentDict'].apply(lambda score_dict: score_dict['neg'])
    df['vader_neu']  = df['sentimentDict'].apply(lambda score_dict: score_dict['neu'])
    df['vader_pos']  = df['sentimentDict'].apply(lambda score_dict: score_dict['pos'])
    df['vader_compound']  = df['sentimentDict'].apply(lambda score_dict: score_dict['compound'])


    return df.drop(columns=["sentimentDict"])

df = pd.read_csv("../data/stack_files/samp_raw_df_april.csv")
df2 = get_sentiment(df)
df2.head()

# %%
scores = sentiment_model.polarity_scores(df_eng["Tweet Text"].tolist()[0])

# %% [markdown]
# ## Fold generation for cross validation

# %%
import random 

def get_folds(df):
    L = list(range(1, 5)) 
    
    q = df.shape[0] // len(L) 
    r = df.shape[0] % len(L)
   
    
    folds = L * q + L[:r]
    
    random.seed(2020)
    random.shuffle(folds)
    
    df["folds"] = folds
    
    return df


df.head()
df3 = get_folds(df)
df3.head()

# df.shape[0] % 4

# %%
df_eng["Tweet Text"].tolist()[0]

# %%
for i in range(150):
    tweet = df_eng["Tweet Text"].tolist()[i]
    score = sentiment_model.polarity_scores(tweet)
    
    print("=" * 100)
    print(tweet)
    print(score)
    print("\n")

# %%
L = []

for i in range(150):
    tweet = df_eng["Tweet Text"].tolist()[i]
    print(tweet)
    
    label = input()
    L.append(label)
    print("Label:", label)

# %% [markdown]
# ## TF-IDF

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
documentA = 'the man went out for a walk'
documentB = 'the children sat around the fire'


vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform([documentA, documentB])
feature_names = vectorizer.get_feature_names()
dense = vectors.todense()
denselist = dense.tolist()
df = pd.DataFrame(denselist, columns=feature_names)

# %%
def get_TF_IDF_mat(list_of_tweets, list_of_IDs):
    vectorizer = TfidfVectorizer()
    vectors = vectorizer.fit_transform(list_of_tweets) # TODO - need to make it generalizable in future
    feature_names = vectorizer.get_feature_names()
    dense = vectors.todense()
    denselist = dense.tolist()
    
    TF_IDF_df = pd.DataFrame(denselist, columns=feature_names)
    TF_IDF_df["ID"] = list_of_IDs # n
    return TF_IDF_df

# %%
df.shape

# %%
df = pd.read_csv("../data/stack_files/samp_raw_df_april.csv")

# %%
df_TF_IDF = get_TF_IDF_mat(df["Tweet Text"], df["ID"])

# %%
df_TF_IDF.head()
df_TF_IDF.describe()

# %% [markdown]
# ## LDA - Topic Modeling

# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.datasets import make_multilabel_classification


lda = LatentDirichletAllocation(n_components=4, random_state=2020) # n_jobs=None

lda_model = lda.fit_transform(df_TF_IDF.iloc[:, :df_TF_IDF.shape[1] - 1])

# %%
lda_model

# %%
def latent_da_v2(X_train, X_test, n_comps):
    lda = LatentDirichletAllocation(n_components=n_comps, random_state=2020) # n_jobs=None 

    return lda.fit_transform(X_train), lda.transform(X_test)

# %%
X_train, X_test = df_TF_IDF.iloc[:100, :-1], df_TF_IDF.iloc[100:, :-1]

# %%
X_test.shape

# %%
X_train2, X_test2 = latent_da_v2(X_train, X_test, 20)

# %%
X_train2

# %%
X_test2

# %% [markdown]
# ## Label some data

# %%
df = pd.read_csv("../data/stack_files/balanced_pro_n_anti_mask_df_v4.csv")

# %%
df.columns

# %%
import numpy as np 
import pandas as pd 


def rater():
    df = pd.read_csv("../data/stack_files/balanced_pro_n_anti_mask_df_v4.csv")
    rating_df = pd.read_csv("../data/stack_files/balanced_pro_n_anti_mask_df_v4_w_ratings.csv")
    
    df2 = df.copy()
    df2["CAP6317_rating"] = [-999] * df.shape[0]
    print(rating_df.shape)

    L = []
    leng = 20 # df.shape[0]
    rater_mat = np.zeros((0, 2))
    left, right = rating_df.shape[0], df.shape[0]
    
    right = 5
    for i in range(left, right):
        print("i:", i)
        print("\n")
        print("=" * 80)
        print("Tweet text:", df.iloc[i, 0])


        print("-" * 80)
        print('Is it an ANTI_MASK tweet? y(1) or n(0)')
        x = input()

        if str(x) == "1" or str(x).lower() == "y":
#             rating = np.array([[df["ID"][i], 1]])
            rating = [[df["ID"][i], 1]
            rating_df.append(pd.DataFrame(rating, columns=["ID", "CAP6317_rating"]), ignore_index=True)  
#             rating_df = rating_df.append(pd.DataFrame(rating, columns=["ID", "CAP6317_rating"]), ignore_index=True)
        elif str(x) == "0" or str(x).lower() == "n":
#             rating = np.array([[df["ID"][i], 0]])
            rating = [[df["ID"][i], 1]
            rating_df.append(pd.DataFrame(rating, columns=["ID", "CAP6317_rating"]), ignore_index=True)
#             rating_df = rating_df.append(pd.DataFrame(rating, columns=["ID", "CAP6317_rating"]), ignore_index=True)
        else:
            print("Input is not accepted. Please, provide a valid response.")
            
#         rater_mat = np.append(rater_mat, rating, axis=0)
            
            
        if i % 3 == 0:
#             print(rater_mat)
#             rating_df = rating_df.append(pd.DataFrame(rater_mat, columns=["ID", "CAP6317_rating"]), ignore_index=True)
            print(rating_df)
            
#             rater_df = pd.DataFrame(rater_mat, columns=["ID", "CAP6317_rating"]) 
            rating_df.to_csv("../data/stack_files/balanced_pro_n_anti_mask_df_v4_w_ratings.csv", index=False, header=True)
                
rater()

# %%
import numpy as np 
import pandas as pd 


def rater():
    df = pd.read_csv("../data/stack_files/balanced_pro_n_anti_mask_df_v4.csv")
    rating_df = pd.read_csv("../data/stack_files/balanced_pro_n_anti_mask_df_v4_w_ratings.csv")
#     print(rating_df)
    
    for i in range(rating_df.shape[0]):
        if rating_df.iloc[i, 1] == -999:
            print(rating_df.iloc[i, 1])
            print("i:", i)
            print("\n")
            print("=" * 80)
            print("Tweet text:", df.iloc[i, 0])

            print("-" * 80)
            print('Is it an ANTI_MASK tweet? y(1) or n(0)')
            x = input()

            if str(x) == "1" or str(x).lower() == "y":
                rating_df.iloc[i, -1] = 1
            elif str(x) == "0" or str(x).lower() == "n":
                rating_df.iloc[i, -1] = 0
            else:
                print("Input is not accepted. Please, provide a valid response.")

            if i % 3 == 0:
#                 print(rating_df)
                rating_df.to_csv("../data/stack_files/balanced_pro_n_anti_mask_df_v4_w_ratings.csv", index=False, header=True)
                
rater()
# Out:
# -999
# i: 0
#
#
# ================================================================================
# Tweet text: RT @TheRightMelissa: @Acosta Neither will I. #nomask because it’s not about “public health” it’s about control. You already demonstrated th…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 1
#
#
# ================================================================================
# Tweet text: so true!!!  #nomasks https://t.co/4QVwCuALqd
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 2
#
#
# ================================================================================
# Tweet text: Happy Labor Day wknd and Greetings from NBC Studios! quick video about precautions this holiday wknd and #COVID19 #vaccine candidates.
#
# #wearamask #PhysicalDistancing https://t.co/RPCRz76Jrt
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 3
#
#
# ================================================================================
# Tweet text: RT @Twitter: The only thing we want going viral is this Tweet
#
# #WearAMask
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 4
#
#
# ================================================================================
# Tweet text: RT @usachris20: Let FREEDOM ring!!!
# 🇺🇸❤️🇺🇸 Now to free Nevada! #RecallSisolak #WeWantJustice #EnoughIsEnough #NoMask https://t.co/ESvJFIsn…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 5
#
#
# ================================================================================
# Tweet text: RT @Scholar_Atheist: Etsy is my online income so i really appreciate RETWEETS. #WearAMask
#
# Excited to share this item from my #etsy shop: F…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 6
#
#
# ================================================================================
# Tweet text: RT @MeidasTouch: Don't be like Donald. #WearADamnMask https://t.co/85mQ73rPCl
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 7
#
#
# ================================================================================
# Tweet text: I read the Mask of the Red Death for the first time; it's a story of decadent rich people cavorting during a deadly plague, seeing somebody with a mask that they don't like, trying to get the mask off him, and then dying horribly.
#
# #TrumpVirus #WearAMask #WearaDamnMask
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 8
#
#
# ================================================================================
# Tweet text: RT @morethanmySLE: "Dr." Karen mocking the man documenting her atrocious behavior at a Florida Costco pleading with her to #WearAMask
#
# #CO…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 9
#
#
# ================================================================================
# Tweet text: 'Lockdown' is simply a new term to justify putting innocent people under house arrest! I have committed no crime therefore any such action is illegal and #idoNOTconsent #lockdown #NoMasks #NOLOCKDOWN #nolockdown2 #lockdownUK
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 10
#
#
# ================================================================================
# Tweet text: RT @sharonstone: Please light candles for my sister Kelly and her husband my dear friend Bruce 🤍🙏🏻🌿 #WearAMask https://t.co/pDblINnJTD
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 11
#
#
# ================================================================================
# Tweet text: RT @nirvidahiya: .@MayoClinic Trust in science.
#
# #WearforAll #WearAMaskSaveALife #MasksSaveLives
# #COVIDー19 https://t.co/XkJK3pmKvy
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 12
#
#
# ================================================================================
# Tweet text: .@honeywell is a Top100 corporate donor to #PA01 incumbent &amp; Trump excuser @RepBrianFitz
#
# Last week, #BoughtAndSoldBrian appeared in Congress, wiping his nose with his fingertips,conspicuously NOT wearing a mask in order to be a McCarthy/Trump #NoMask tribalist
#
# #MaskUpFitz 😷 https://t.co/i8nYgLYT57
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 13
#
#
# ================================================================================
# Tweet text: RT @TheRightMelissa: @Acosta Neither will I. #nomask because it’s not about “public health” it’s about control. You already demonstrated th…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 14
#
#
# ================================================================================
# Tweet text: @PeterSweden7 You bet. #ScumMedia #NoMasks. https://t.co/ydgZ4XJ2KU
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 15
#
#
# ================================================================================
# Tweet text: @DaxGigandet Mask mandate country wide with stiff penalties for violations. Enough with the Karen’s. #WearAMask
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 16
#
#
# ================================================================================
# Tweet text: RT @LawJSharma: We’re officially living in a Parks and Rec episode. #WearAMask https://t.co/LknwwdYmvF
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 17
#
#
# ================================================================================
# Tweet text: RT @paint_texas: #NoMask #NoMasks #Coronvirus #MAGA
#
# No Mask Shopping ..... 🤣 https://t.co/dFnnIGZbqr
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 18
#
#
# ================================================================================
# Tweet text: #WearAMask, safely enjoy Chinatown today and then swing on by the Oakland waterfront for a nice top off to the evening @visitoakland @JackLondonSq #oakland https://t.co/8DNdpkfbTp
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 19
#
#
# ================================================================================
# Tweet text: RT @WithDaughters: If Maxwell and Finnegan can wear their masks and be happy about it you can too #WearAMask #BeatCOVID19
#
# @PattyArquette…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 20
#
#
# ================================================================================
# Tweet text: #Garden #Bunny Face Mask Green Orange Cotton #Watering Can Washable #Reusable Designer Fabric Cover Kids / Adult / Handmade in USA  https://t.co/drMjBsmi5D  #etsyhandmade #gardening #farmersmarket #florist #facemask #facemasks #WearAMask #staysafe #facecovering #giftideas https://t.co/8ybigRAeTC
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 21
#
#
# ================================================================================
# Tweet text: RT @RedDragonFly19: Wow, this is Barcelona
# #NoMasks #NoMoreFakeCases #NoLockdowns
# #Trump2020LandslideVictory #MakeEarthGreatAgain https://t…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 22
#
#
# ================================================================================
# Tweet text: RT @JUSTICETIME7: @LeahR77 Tina and Ben nail it. #NoMasks @GrrrGraphics are propaganda and MindWarfare® https://t.co/CF1IJOGhQd
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 23
#
#
# ================================================================================
# Tweet text: Alternative Government https://t.co/76ipSX9WH4 #KBF #NoMasks #Covid19UK
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 24
#
#
# ================================================================================
# Tweet text: RT @DrTedros: Thank you, #BTS for the uplifting #BTS_Dynamite and for reminding the #BTSARMY and the rest of us to #WearAMask and take care…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 25
#
#
# ================================================================================
# Tweet text: @portarican_RT I’m with you in spirit. So thankful for my fellow healthcare workers and all they are sacrificing to get people through a horrible illness.
# Stay safe. #WearADamnMask
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 26
#
#
# ================================================================================
# Tweet text: PCR false positive lies #COVID19 #PCRtest #MattHancock #KBF #NoLockdowns #NoMasks #NoTrackAndTrace #NoVaccine https://t.co/BBuUAuH4jA
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 27
#
#
# ================================================================================
# Tweet text: Dahlia bed love T 💟
#
# #lovemygarden #london #sharethelove #mytropicalparadise #mentalhealth #inspiration #bekind #endthelockdown #endsocialdistancing #wakeup #NoMasks #KeepBritainFree https://t.co/S8C0tp2z4c
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 28
#
#
# ================================================================================
# Tweet text: Protect your fellow associates. Protect your families. Protect yourself. #WearAMask https://t.co/TSgaRfNeuf
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 29
#
#
# ================================================================================
# Tweet text: RT @DrTedros: Thank you, @BTS_twt J-Hope for reminding #BTSARMY to #WearAMask as families gather together and celebrate #ChuSeok holiday th…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 30
#
#
# ================================================================================
# Tweet text: RT @mbfrat: 🚨MASKS DO NOT WORK🚨
#
# #MasksDontWork #Masks
# #MasksOffAmerica #NoMasks
# #MasksOff #BarefacedInPA
# #EndTheNightmare
# #WeLoveYouTru…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 31
#
#
# ================================================================================
# Tweet text: RT @VBermoothes: That’s why I will never wear a mask.
#
# #NoMasks #NoApp #NoNewNormal
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 32
#
#
# ================================================================================
# Tweet text: The heroes we may never see but they make sure we are feed and have products on the selves to consume. $15 minimum wage ain’t much to ask for! ❤️✊🏽 #WearAMask #ProtectYourself https://t.co/Z7rSnrHsRd
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 33
#
#
# ================================================================================
# Tweet text: RT @jaicabajar: Click the heart and see if it works #WearAMask
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 34
#
#
# ================================================================================
# Tweet text: My husband was wearing a mask in the grocery store yesterday. He got so dizzy he almost passed out!
# #NoMask for him anymore. Luckily he’s Covid free.
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 35
#
#
# ================================================================================
# Tweet text: Wearing masks while stepping outside the house is mandatory and they should cover the mouth and nose, @RAKRI1 said on Thursday, adding that people must not touch their masks with their hands
# #WearAMask
# #WearAMaskSaveALife
# #Covid19Chennai
# @NewIndianXpress
# https://t.co/N2POVXP7CE
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 36
#
#
# ================================================================================
# Tweet text: RT @itsbr0gan: Just a little something for all the idiots on the #NoMasks thread 🥰🥰 https://t.co/7qoGEUELMo
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 37
#
#
# ================================================================================
# Tweet text: Tearing up.  Covid gets real, taking out the innocent just doing their jobs. #COVID19  #WearADamnMask https://t.co/mTS3bP6Xou
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 38
#
#
# ================================================================================
# Tweet text: @GovMikeDeWine Fuck you #NoMasks
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 39
#
#
# ================================================================================
# Tweet text: @ARIZONA2A @billgatesaz @ClintLHickman is NOT getting any votes from our household for the perpetual county mask mandate!
#
# We don’t buy Hickman eggs anymore either. 🐔🥚🍳
#
# Four RINOs &amp; a Democrat decided masks for the 4.5 million in Maricopa.
#
# #NoMaskMandates #NoMasks
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 40
#
#
# ================================================================================
# Tweet text: @itstonybennett It takes strength to wear something uncomfortable.
# It takes self-esteem to wear something unattractive.
# It takes intelligence to wear something safe.
# It takes kindness to wear something for the greater good.
#
# It takes a leader that knows this.
#
# #VoteBidenHarris2020 #WearAMask
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 41
#
#
# ================================================================================
# Tweet text: RT @1SpencerGarrett: Just gonna leave this here. The right people will get it. #WearAMask https://t.co/oRIKboHvQu
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 42
#
#
# ================================================================================
# Tweet text: RT @CoronaDoubter: So what  ! who cares ? she knew its no worse than a bad cold  #Covid19 #NoMasks  SNP MP Ferrier visited gym, gift shop &amp;…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 43
#
#
# ================================================================================
# Tweet text: It’s come to this in @BellwoodsPark - glad it’s in place, but sad it had to be this way. #pandemic still with us. #keepsafe #SocialDistancingWorks #WearAMask 😷 https://t.co/nT9XLc2ztn
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 44
#
#
# ================================================================================
# Tweet text: RT @TheRightMelissa: @Acosta Neither will I. #nomask because it’s not about “public health” it’s about control. You already demonstrated th…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 45
#
#
# ================================================================================
# Tweet text: Like for another cool surprise :)
# #WearAMask
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 46
#
#
# ================================================================================
# Tweet text: RT @EmilyAinCA: I feel like I would not be able to preventatively check myself into a hospital. #COVID19 #GOPSuperSpreaders #WearAMask
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 47
#
#
# ================================================================================
# Tweet text: #SantaMonica will begin targeted enforcement for face coverings in business districts &amp; parks this week.
#
# Save $100 &amp; save your health by masking up 😷✌️🌴#WearAMask https://t.co/exVGKSjL4L
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 48
#
#
# ================================================================================
# Tweet text: Drop the hammer Mr. President..!!!
# The Storm is Upon US...!!!
#
# #ObamaGate
# #ArrestSoros
# #AntifaBLMDomesticTerrorists
# #LockHerUp
# #MSMisLiable
# #VoteRedToSaveAmerica2020
# #LawAndOrder
# #2A
# #NoMasks
# #VoterID
# #EndCensorship
# #DNCPedoParty
# #BidenRiots
#
# #GodWins
# #TrumpWins https://t.co/RNCzdRWKwl
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 49
#
#
# ================================================================================
# Tweet text: RT @GP_daww: Mask or respirator, you have to ponder and choose one out of the two, so stay safe and wear a mask. @fessykid
# #WearAMask @YUV…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 50
#
#
# ================================================================================
# Tweet text: @EmersonBrophy Not to bring the crowd down but I just wrote a piece about the importance of wearing a mask. Let's keep singing this song!  #wearamask
# https://t.co/hFWH82ORMm
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 51
#
#
# ================================================================================
# Tweet text: @Lakers Is @KingJames advocating for not wearing a mask? If so, I am in!!! Thank you for being a voice of reason against these stupid masks! #NoMask
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 52
#
#
# ================================================================================
# Tweet text: RT @DrTedros: Thank you, @BTS_twt J-Hope for reminding #BTSARMY to #WearAMask as families gather together and celebrate #ChuSeok holiday th…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 53
#
#
# ================================================================================
# Tweet text: @Cyberbeagle1 @jackbuck123 @mattforde 😂😂😂😂 so you will wear a mask but when there’s a vaccine you won’t. But surely wearing a mask will still prevent you passing on the virus to someone who may not have been vaccinated. Oh well I wish you well. #ENDLOCKDOWNNOW #NoMasks 😀👍🇬🇧
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 54
#
#
# ================================================================================
# Tweet text: RT @PatriotPottery: Brilliant. #OpenOhioNow #OpenPA #NoMask https://t.co/QsDdMkxY6X
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 55
#
#
# ================================================================================
# Tweet text: The people supporting #NoMasks were the same people clapping for the NHS. Evidently their support doesn't go as far as wearing a thin piece of fabric for half an hour in a shop. What heroes.
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 56
#
#
# ================================================================================
# Tweet text: RT @sebroche: Do you get it now? Wear a mask you f*cking idiots! #WearADamnMask
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 57
#
#
# ================================================================================
# Tweet text: @DesmondSwayne  Here is a message for you and your constituents. #nomasks #coronavirusuk https://t.co/1R9rXTQr9u
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 58
#
#
# ================================================================================
# Tweet text: Hello .@SteveJCordes isn’t @Healthmac on the board of directors at YOU? Has he been made aware of these expectations? Hoping he can start representing all citizens of #ldnont including the awesome youth you inspire every day. #WearAMask #SelfIsolate #14days https://t.co/6Ua0ugJVgf
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 59
#
#
# ================================================================================
# Tweet text: Open mic moment. - hoax, everyone's been vaccinated any way, case death rate is 0.1, no need for masks #COVID19 #Hotmic #Vaccinated #NoMasks https://t.co/oyNTy07dvF
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 60
#
#
# ================================================================================
# Tweet text: RT @tanya_1299: Safety isn't expensive, it's priceless
# #WearAMask @campaignyolo @WHO @YUVSTRONG12 https://t.co/1sBZXpWTuG
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 61
#
#
# ================================================================================
# Tweet text: #CommonSense is the least common of the senses
# #PhotographyIsMyPassion #Photography #PhotographyIsArt #PhotographyIsLife #BlackAndWhitePhotography #BlackAndWhite #NoirEtBlanc #NoirEtBlancPhotographie #Fotografia #ArtPhotography #TheGym #Mask #NoMask #WearAmask #Idiot #CovidIdiots https://t.co/fAxgWa9WGS
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 62
#
#
# ================================================================================
# Tweet text: Neurologist sounds alarm on masks - Masks will cause neurological damage. The damage cannot be reversed by ceasing to wear a mask
#
# We're set to have a explosive growth in zombie
# #Scamdemic #Plandemic #NoMasks #MasksDontWork #MasksOff https://t.co/auMeyb42YP
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 63
#
#
# ================================================================================
# Tweet text: @ColleenHuberNMD Fauci: “We Should Not Be Wearing Masks.
#
# There Are UNINTENDED CONSEQUENCES From It...”.
#
# Seems To Be What They Want.
#
# 60 Minutes Clip. March ‘20
#
# #BackToNormal
# #HerdImmunity
# #NoMasks
#  #Constitutional Lawyers.
#
# https://t.co/V54fKkr6L4
#
# Link
# https://t.co/tCStRmEN0z https://t.co/RPnY0ik1mg
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 64
#
#
# ================================================================================
# Tweet text: RT @Amber02150: Wishing everyone a great weekend 🍂
# Enjoy the fall and its amazing colors 🍁
# #StaySafe
# #WearAMask
#
# 🍂🍃🍁 https://t.co/eRPCfor…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 65
#
#
# ================================================================================
# Tweet text: 6 #COVID19 facts the #MSMIsTheEnemyOfThePeople won't report.
#
# #ChineseVirus
# #China
# #NoMasks
#
# https://t.co/V8PD84rFBI via @YouTube
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 66
#
#
# ================================================================================
# Tweet text: RT @TheRightMelissa: @Acosta Neither will I. #nomask because it’s not about “public health” it’s about control. You already demonstrated th…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 67
#
#
# ================================================================================
# Tweet text: RT @BionicBirdAnna: My takeaway from this are these two screenshots. FFS please,  #StayHomeSaveLives #WearAMask https://t.co/sPbr2C9Usa htt…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 68
#
#
# ================================================================================
# Tweet text: Where is it written in our Constitution
# that you have the right to demand I
# wear a covering over my face?  This
# is not Iran! No law has been passed!
# #NoMask #NoTest #NoVaccineForMe https://t.co/eTEtw4dfdL
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 69
#
#
# ================================================================================
# Tweet text: This is why, even if you don't want to wear a mask you still should.. Next time it could be you or your loved ones.. #stopbeingselfish #WearAMaskSaveALife https://t.co/2bau1FA62V
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 70
#
#
# ================================================================================
# Tweet text: RT @SidneyPowell1: GOOD DECISION!
# Georgia Governor Bars Cities, Counties From Requiring Masks to be Worn https://t.co/lhlCfovuTA
# #NoMasks c…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 71
#
#
# ================================================================================
# Tweet text: I love it. Barr: #NoMask 💪👊🔥 https://t.co/CJvfQdQwVP
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 72
#
#
# ================================================================================
# Tweet text: If people give into masks, which do nothing, they will give into mandatory vaccines... Better fight the mask mandates or you will loose more than one freedom. #boycottWalmart, #nomasks
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 73
#
#
# ================================================================================
# Tweet text: RT @hfxtransit: In support of public health recommendations, we strongly encourage our riders to please #wearamask when possible. To help,…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 74
#
#
# ================================================================================
# Tweet text: @mhdksafa No issues #WearAMask
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 75
#
#
# ================================================================================
# Tweet text: Today I am lifted up by this beautiful child. From this day forward, when I #WearAMask I will feel a crown on my head. https://t.co/ELF7s9JHxX
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 76
#
#
# ================================================================================
# Tweet text: RT @FoxNewsMom: @GavinNewsom You’re keeping the hysteria alive, creep.
#
# #NOMASKS
#
# #OPENCALIFORNIA https://t.co/ZiD1VDr8gZ
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 77
#
#
# ================================================================================
# Tweet text: Sweden flattened the curve by doing nothing #nomask https://t.co/nyQgmgjIEJ
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 78
#
#
# ================================================================================
# Tweet text: @peachshouto 😹👍 good post riley !! i hope the kids are good and peter is still kicking !! cant wait to see you at the anti-vax bbq next weekend !! remember no masks !! #nomasks #covidisahoax
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 79
#
#
# ================================================================================
# Tweet text: RT @BasiaC7: Ok, so I had a fun afternoon.
#
# I went to Target with #NoMask &amp; someone had called the the Police on me. Had a pleasant discus…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 80
#
#
# ================================================================================
# Tweet text: @TheRealPhilX 100% . I don’t understand people who won't wear a mask. Participate in humanity and protect each other.  It's not that hard.  #WearAMask
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 81
#
#
# ================================================================================
# Tweet text: Such a simple solution! 😷 #WearADamnMask #coronavirus #Airborne #SocialDistancing @Surgeon_General https://t.co/1p0My6HK3c
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 82
#
#
# ================================================================================
# Tweet text: RT @kbeanie93: Say it louder for the bedwetters + compliant sheep in the back 📢📢📢 #CovidHoax #Scamdemid #KBF #KeepBritainFree #NoMask #NoMa…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 83
#
#
# ================================================================================
# Tweet text: @tnewtondunn Masks are bad science. Feels like Nicola Sturgeon and others wanna prolong lockdown by stalling inevitable spread to herd immunity to heap worse economic pain on us to go crawling back to EU! Here's the best explanation I've seen why #NoMasks for #Covid19
# https://t.co/tN6Ul8Yt3q
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 84
#
#
# ================================================================================
# Tweet text: If you don't live in the US or are part of the ultra left wing London based media, you would know lots of traditional left wing and Labour voters have opposed Eu and face coverings in the North of England. #NoMaskOnMe #NoMasks
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 85
#
#
# ================================================================================
# Tweet text: RT @reIagz: Tap the like button it’s so cool #WearAMask https://t.co/Qex4cprJff
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 86
#
#
# ================================================================================
# Tweet text: RT @sfpelosi: We’re still in the FIRST wave of #covid. Put pride aside: #WearAMask!
#
# Jim Cramer: “A lot of people won't wear a mask. They…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 87
#
#
# ================================================================================
# Tweet text: @dominiquetaegon If there is a #police enforced instant #fine of £100 for not wearing a mask then being stopped and searched and then found in possession #knives or #drugs then must be at least a 5year sentence . #nomask #liberty
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 88
#
#
# ================================================================================
# Tweet text: can we just stop this whole #NoMasks debate and just wear a mask. if you have a serious reason why (wether that’s a seen or hidden condition that the mask will negatively impact) then fair enough. if not just 🤫🤫 and wear a mask it’s not hard
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 89
#
#
# ================================================================================
# Tweet text: Simple as that!!  #NoMasks #wwg1wgaWorldWide https://t.co/fNOtGCga4r
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 90
#
#
# ================================================================================
# Tweet text: #Hope #USA #CoronavirusOutbreak @FAANews #FAA order it, #Airlines passengers #WearAMask don't be part of #TrumpGenocide https://t.co/AlRi8Hi22W
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 91
#
#
# ================================================================================
# Tweet text: This week's #AngelasSoapBox:
#
# #Democrats: the Party of #NotScience!
#
# Today's Democrats are modern-day alchemists who think they can turn sh*t into gold. Arrogant &amp; stupid as the day is long.
#
# Please share!
#
# #Trump2020 @TrumpWarRoom #NoMasks #LiveFreeOrDie
#
# https://t.co/MroDPVp6E5
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 92
#
#
# ================================================================================
# Tweet text: RT @middleageriot: Wearing a mask during a pandemic is not political.
#
# Not wearing one is.
#
# #WearADamnMask
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 93
#
#
# ================================================================================
# Tweet text: Do you know how to correctly put on &amp; remove your #facemask?
#
# https://t.co/kfKZXvXlXc
#
# #facemasks #mask #protectyourself #protectothers #nomasks #TypeIIR #KN95 #FFP2 #3ply #3layer https://t.co/nk0y4hNnkG
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 94
#
#
# ================================================================================
# Tweet text: Back up to 18.8 percent positive. Unless I missed it, nothing from state “leadership” @henrymcmaster in terms of any plan to right this ship. #WearADamnMask https://t.co/JVhQUtdxyA
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 95
#
#
# ================================================================================
# Tweet text: RT @TheRightMelissa: @Acosta Neither will I. #nomask because it’s not about “public health” it’s about control. You already demonstrated th…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 96
#
#
# ================================================================================
# Tweet text: Yesterday. Travelled by tube and train from London to stay with friends in East Anglia. First time on the railways since March. No mask on either. Not challenged but a few sour looks from fellow passengers. Oh well. I thoroughly enjoyed exercising my freedom.
#
# #NoMask
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 97
#
#
# ================================================================================
# Tweet text: #SPAIN has mandatory masks outdoors as well as indoors.
#
# Does these mean - good golly GOSH! - masks DON'T WORK?
#
# #WarOnMasks #NoMasks #CovidHoax #BMJAnalysis #MasksOff
#
# @piersmorgan @HeleneMarivdW @deb_cohen @bmj_latest @MayorofLondon @SadiqKhan @MattHancock @BorisJohnson https://t.co/OAUjiZ5KE3
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 98
#
#
# ================================================================================
# Tweet text: #NoNewNormal #StopTheMadness #NoMasks #WakeUp #LiberalAgenda No thanks 👋 https://t.co/qxbfgcMeKM
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 99
#
#
# ================================================================================
# Tweet text: RT @DrRobDavidson: I #WearAMask for my entire shift in the ER. There are ZERO harmful effects of wearing a mask, and you could save someone…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 100
#
#
# ================================================================================
# Tweet text: RT @stevelanebitch: Doctor explains why masks are horribly wrong for kids. #nomasks full vid here. https://t.co/2mwET4Ug0h https://t.co/ZcM…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 101
#
#
# ================================================================================
# Tweet text: RT @nikkifried: Mississippi now has a #WearAMask mandate.
#
# Mississippi.
#
# Let’s go, @GovRonDeSantis.
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 102
#
#
# ================================================================================
# Tweet text: RT @JackDunc1: #NoMasks people be like "no I will NOT wear a cheap and simple piece of fabric over my face to stop vulnerable people dying…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 103
#
#
# ================================================================================
# Tweet text: RT @SidneyPowell1: #Masks don't work and are not good for us
# Stop the foolishness
# https://t.co/I1liMn3hzB
# #NoMasks
# Protect yourself as yo…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 104
#
#
# ================================================================================
# Tweet text: Coronavirus 'being spread by asymptomatic young people', warn WHO - follow live https://t.co/F8m5QSSjtI #KeepDistance #WearAMask #WashYourHands @SDicht
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 105
#
#
# ================================================================================
# Tweet text: We've been on #COVID19 lockdown for 192 days at the time of posting. Keeping my kids safe is my main purpose in life right now. That said, it's incredibly important that we also focus on emotional wellness as well. We spend time in nature to help with that. #WearAMask https://t.co/B6UXWrg7cE
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 106
#
#
# ================================================================================
# Tweet text: RT @KNGillespie: @realDonaldTrump But only 1 public health consensus - wear a mask to protect others. #WearAMask #TrumpDepression #TrumpDea…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 107
#
#
# ================================================================================
# Tweet text: Day 65 of let's drink a Coffee/Tea/... together ☕🍵
#
# They're back and I'm on the Menu List 😢🙈😂 you too???
#
# #YouAreNotAlone
# #randomhearts ♠❤💛
# #stayconnected #staysafe
# #wearamask😷 #washyourhands
# #angelsofkeanureeves @AngelsOfMrKCR https://t.co/pbM6hGQCMs
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 108
#
#
# ================================================================================
# Tweet text: @NotHoodlum @ReesusP 🎶
# You're so vain
# You probably think a facemask's about you
# Your so vain
# I'll bet you think protection's about
# Don't you?
# Don't you?
#
# #WearAMask
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 109
#
#
# ================================================================================
# Tweet text: To those massive snowflakes who cancelled their Tory membership because of a mask but not because of Austerity, Xenophobia, Teacher, Nurse, Police or Health care worker bashing, fraud, contracts for their mates, wasting public money. You really are a spineless cunt.
# #NoMasks
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 110
#
#
# ================================================================================
# Tweet text: @SaraCarterDC @tedcruz @AmericanAir https://t.co/dPOUNcBZv0 the truth always comes out!! #nomask
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 111
#
#
# ================================================================================
# Tweet text: Richard Ebright is a highly qualified expert who recommends that EVERYONE wear a protective mask.
#
# @R_H_Ebright knows what he’s talking about. Listen to him.
#
# #WearAMask https://t.co/mhizglns2B https://t.co/sms8rhOVkR
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 112
#
#
# ================================================================================
# Tweet text: RT @drfixus: Thanks @uabmedicine !
# #WearAMask
# #SaveALife
# #TeamHumanity https://t.co/wKc0GXF6Ud
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 113
#
#
# ================================================================================
# Tweet text: @SenMikeShirkey What does it take to convince you to send the right message?
# Should we all be hospitalized 1st?
# #WearADamnMask
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 114
#
#
# ================================================================================
# Tweet text: RT @TrumpyQGirl: @FreeTheTruth1 @shaenaboo Their symbols will be their downfall.  These people are stupid.  #NoMasks   #SaveTheChildren
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 115
#
#
# ================================================================================
# Tweet text: fcuking idiots
#
# every single one of them
#
# THANKS FOR THE BREATH OF DEATH
#
# #NoMasks #KBF #endthelockdownuk #covidhoax #COVIDIOTS  FCUK OFF
#
# #Covid19UK #zombies
# #londonprotest
#
# #WearAMask
# #WearADamnMask
#
# #StayHome #SaveLives https://t.co/BqfluOKO4L
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 116
#
#
# ================================================================================
# Tweet text: THIS is what we need to do ALL OVER AMERICA!!!
#
# #CallToActionAmerica
#
# #NoMask demonstrations in EVERY city/town in the US of A
#
# August 15/16
# August 22/23
# August 29/30
#
# Start organizing!
# #WWG1WGA https://t.co/DR5lUMSMIl
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 117
#
#
# ================================================================================
# Tweet text: RT @CllrBSilvester: We should protect the vulnerable..... but let the rest of us go free.
# #EndlockdownNOW
# #NoMasks
# It is crucial for the w…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 118
#
#
# ================================================================================
# Tweet text: Come on Colorado - take care of each other and #WearADamnMask https://t.co/nAhoaq7l6v
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 119
#
#
# ================================================================================
# Tweet text: RT @aandrewwz: THIS THE ONE, STOP WHAT YOU DOING AND LIKE THIS #WearAMask https://t.co/tdK56Fy4jE
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 120
#
#
# ================================================================================
# Tweet text: Please share this #WearAMaskSaveALife https://t.co/Hd4LS9gwom
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 121
#
#
# ================================================================================
# Tweet text: I f you follow the words of Christ and “Love your neighbor as yourself” then #WearAMask should be a pleasure because it helps those around more than probably ourselves!
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 122
#
#
# ================================================================================
# Tweet text: RT @jay_jagannathan: Tune in
#
# But dont forget that to #PreventCOVID19Spread we need to #WearAMask when in public, #WashYourHands and mainta…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 123
#
#
# ================================================================================
# Tweet text: RT @DrTedros: Thank you, #BTS for the uplifting #BTS_Dynamite and for reminding the #BTSARMY and the rest of us to #WearAMask and take care…
# ...
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 285
#
#
# ================================================================================
# Tweet text: NEW @BoyMeetsGirlusa x @Survivor_Corps MERCH!
#
# New hoodies, sweatpants, and more - now on our site. 50% of the net proceeds goes to @Survivor_Corps: https://t.co/kigNhQROZ2
#
# #WearAMask #WearADamnMask #BOYMEETSGIRL x #SURVIVORCORPS
#
# ♥️♥️♥️ https://t.co/UVR9oneOYO
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 286
#
#
# ================================================================================
# Tweet text: RT @Brixton_Ben26: Good to see that #nomasks is trending. At least there are still a few sane people around.
#
# Lets keep it trending everyo…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 287
#
#
# ================================================================================
# Tweet text: RT @Hotlegs101_art: Some safety precautions for the pandemic! (1/2)  #stayinside #covid19 #washyourhands #wearamask #wearyourmask #staysafe…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 288
#
#
# ================================================================================
# Tweet text: RT @marcusy_: WTF THIS WORKS REMEMBER TO #WearAMask https://t.co/7JuSXEENef
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 289
#
#
# ================================================================================
# Tweet text: COVID-19: Cross River commences enforcement of https://t.co/HDrw7RJ5Ym #covid19 #nomask
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 290
#
#
# ================================================================================
# Tweet text: @INFORMS Practice webinar: @jlswann explains how the combination of #WearAMask compliance &amp; mask quality reduces the spread of #COVID__19.
# Research details: https://t.co/tHxbBa7aqz
#
# @CHHSgatech @NCStateISE #InfectiousDiseases #Analytics
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 291
#
#
# ================================================================================
# Tweet text: @FranMFarber @RealCandaceO The TRUTH is that more than 186,000 Americans have died of Covid.  Candace is spreading LIES.
# #WearAMask
# #CandaceIsACovidiot
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 292
#
#
# ================================================================================
# Tweet text: RT @NYGovCuomo: It’s up to us. #WearAMask https://t.co/GDSXGlNij3
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 293
#
#
# ================================================================================
# Tweet text: Makeni flyover bridge this morning!!
# #covid19
# #socialdistancing
# #wearamask
# #stayhome
# #staysafe https://t.co/vrpvFaJsoG
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 294
#
#
# ================================================================================
# Tweet text: RT @MuellerLiesche: Zitat des Tages:
#
# „A mistake repeated more than once is a decision.“
#
# #WearAMask
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 295
#
#
# ================================================================================
# Tweet text: A cautionary warning on community #covid19 exposure from @neurooruen, a former resident &amp; friend.
#
# Without widespread masks &amp; w/📈cases, we on the #frontline can't see a way to let our guard down in 2020 in &amp; out of the hospital.
#
# That is hard to sustain.
#
# #WearAMask
# #UABUnited https://t.co/aIGi5D4qyT
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 296
#
#
# ================================================================================
# Tweet text: With #COVID19 cases surging, reports of #testing delays &amp; shortages, #PPEshortage still a problem, hospitals at capacity, and needing to remind the public to #StayAtHome, use #HandHygiene #WearAMask and #PhysicalDistance who feels like we are back in March 2020?
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 297
#
#
# ================================================================================
# Tweet text: @LukeMor19529310 They will still try to enforce/coerce ppl to take unproven vaccine.
#
# #NoVaccine #NoMasks
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 298
#
#
# ================================================================================
# Tweet text: Getting COVID is just the start. The coronavirus is now known to attack many parts of the body beyond the respiratory system, causing damage from the eyeballs to the toes, the gut to the kidneys. #WearADamnMask https://t.co/qyXPrQ1BAr
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 299
#
#
# ================================================================================
# Tweet text: RT @TheRightMelissa: @Acosta Neither will I. #nomask because it’s not about “public health” it’s about control. You already demonstrated th…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 300
#
#
# ================================================================================
# Tweet text: The Left's push for mandatory face masks is full throttle, even in my state of Indiana.
#
# Governor Holcomb so far is not indicating he will ever issue an executive order to mandate. Doesn't matter, I will NEVER submit!
#
# It's a violation of the 10th Amendment anyway!
#
# #NoMasks
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 301
#
#
# ================================================================================
# Tweet text: RT @DrRobDavidson: I #WearAMask for my entire shift in the ER. There are ZERO harmful effects of wearing a mask, and you could save someone…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 302
#
#
# ================================================================================
# Tweet text: @DVATW Absolutely. Politicians will milk this one for all its worth.
#
# #NoMasks
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 303
#
#
# ================================================================================
# Tweet text: A new study demonstrates that the fabrics typically used in homemade face masks effectively block droplets that could contain SARS-CoV-2.
# https://t.co/ir6mEXACXZ
# #COVID19 #coronavirus #WearAMask #MasksWork
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 304
#
#
# ================================================================================
# Tweet text: RT @RedWolfe45: I cant breath if I wear a mask in Las Vegas where its 110 at 7:30 PM!! #nomask https://t.co/kcoC1AzV7x
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 305
#
#
# ================================================================================
# Tweet text: New!
# Sheeple masks!
# These are by popular demand through emails, Facebook posts, Twitter and Instagram comments!
#
# Design by @GregOnSports
#
# #sask #sheeple #WearAMask https://t.co/FtOlQbofyt
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 306
#
#
# ================================================================================
# Tweet text: .@radiostradbroke https://t.co/Hkr6XDbDac #StaySafe #WearAMask #stayconnected #NowPlaying Soft Cell - Say Hello, Wave Goodbye
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 307
#
#
# ================================================================================
# Tweet text: @PunishDem1776 Life as we knew it will never be the same. The good news is we, together, will shape society and communities with awake/aware enlightened service providers, stores, farms, barder etc. This includes education. Can't go back but we can rebuild it ALL...now.
# #NoMask #IDoNotConsent
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 308
#
#
# ================================================================================
# Tweet text: Without you @JoeBiden @KamalaHarris #NoMasks #Nomasks #BurnTheMask @POTUS @CDCgov #COVID19 #vaccine failure. https://t.co/uxEwZ1u9ty
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 309
#
#
# ================================================================================
# Tweet text: 🥳🥳🥳🥳 #WearAMask #BeSmartBeSafe this is so exciting! https://t.co/fS5frfwlyy
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 310
#
#
# ================================================================================
# Tweet text: @V5M1000 @InProportion2 #NoMasks So many don’t seem to understand. My objections meet with. “it’s like wearing a scarf &amp; courteous &amp; considerate. &amp; similar nonsense. It is not like the above at all. Mask’s always meant exactly that; masking the person, hiding him/her, cancelling the real self.
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 311
#
#
# ================================================================================
# Tweet text: RT @DrEricDing: OMG! Who did this?!?! Best 2 minutes of your day, week, month, maybe year.
#
# #WearAMask #SleepingBeauty #COVID19 #Masks #Ma…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 312
#
#
# ================================================================================
# Tweet text: RT @5D_Justice: Here it comes the boomerang #NoMask
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 313
#
#
# ================================================================================
# Tweet text: I hope thousands of people in the Cleveland area don't descend on the venue to yell this throughout the debate, actually. #WearAMask #TrumpLiedPeopleDied https://t.co/E2PVnxkbcR
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 314
#
#
# ================================================================================
# Tweet text: An important message is lighting up in Saskatoon and Regina! #WearAMask Watch for more on this to come! https://t.co/I2Gv2VhLNM
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 315
#
#
# ================================================================================
# Tweet text: 💜hello my dear friends happy day💜🙏  #myfoto #StaySafe #StaySafeStayHealthy #WearYourMask #WearAMask https://t.co/bW4IU9Rp50
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 316
#
#
# ================================================================================
# Tweet text: 990,000 Fewer #Coronapalooza Goers Showed Up To #tRumpRallyFail, Didn't #WearAMask😷,  Moved Freely In &amp; Out Of The CoronaDome &amp; Bunched Together SuperSpreading Germs. The Overflow Was Cancelled. Thanks #Zoomers &amp; #kpopstans
# https://t.co/wbp53NEHfP
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 317
#
#
# ================================================================================
# Tweet text: RT @democraticbear: Florida is collapsing and DeSantis is doubling down on his lies.
#
# #WearAMask
# #IndictDeSantis
# https://t.co/JMIdAeGV9d
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 318
#
#
# ================================================================================
# Tweet text: Idaho. Please wear a mask. Our hospitals need your help. We are short on PPE. Testing is near capacity. Hospitals are filling up.  https://t.co/S5EvYtuWHR #WearADamnMask #StopTheSpread #idahoCovid19 https://t.co/eBX7R5RZP4
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 319
#
#
# ================================================================================
# Tweet text: RT @andrew_bogg: #NoMasks If you really don't like to wear a mask...imagine how much you are going to hate this non invasive ventilation ma…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 320
#
#
# ================================================================================
# Tweet text: I dream of skipping through Sainsbury’s wearing only a nice fitting cloth face covering. And the rest of my clothes, obviously. That would be a goddamn delight #WearAMask https://t.co/SFTT4QB5gI
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 321
#
#
# ================================================================================
# Tweet text: RT @johnlegend: Everyone, please #WearAMask and social distance this weekend and for  the foreseeable future until we beat this disease!  R…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 322
#
#
# ================================================================================
# Tweet text: This is brilliant!! #NoMasks #KeepBritainFree https://t.co/gqmZOQKVcp
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 1
# -999
# i: 323
#
#
# ================================================================================
# Tweet text: Trump was busy coming up with nicknames for his rival tweets during that briefing. #TRE45ON #TraitorTrump #RepublicansForBiden #RepublicansAgainstTrump #WearAMask https://t.co/3DYmhTGJDW
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)
# 0
# -999
# i: 324
#
#
# ================================================================================
# Tweet text: RT @Renee53211: Time to #EndTheShutdown and fully open our country. And #nomasks as they don’t work and they are another sign of oppression…
# --------------------------------------------------------------------------------
# Is it an ANTI_MASK tweet? y(1) or n(0)

# %%
df = pd.read_csv("../data/stack_files/balanced_pro_n_anti_mask_df_v4.csv")

df2 = df[["ID"]]
df2["CAP6317_rating"] = [-999] * df2.shape[0]

df2.shape

df2.to_csv("../data/stack_files/balanced_pro_n_anti_mask_df_v4_w_ratings.csv", index=False, header=True)

# %%
df2.dtypes

# %%
from nltk import agreement
rater1 = [1,1,1]
rater2 = [1,1,0]
rater3 = [0,1,1]

taskdata=[[0,str(i),str(rater1[i])] for i in range(0,len(rater1))]+[[1,str(i),str(rater2[i])] for i in range(0,len(rater2))]+[[2,str(i),str(rater3[i])] for i in range(0,len(rater3))]
ratingtask = agreement.AnnotationTask(data=taskdata)
print("kappa " +str(ratingtask.kappa()))
print("fleiss " + str(ratingtask.multi_kappa()))
print("alpha " +str(ratingtask.alpha()))
print("scotts " + str(ratingtask.pi()))
# Out:
# kappa -0.1666666666666667
# fleiss -0.2000000000000003
# alpha -0.1428571428571428
# scotts -0.28571428571428603

# %%
taskdata
# Out:
# [[0, '0', '1'],
#  [0, '1', '1'],
#  [0, '2', '1'],
#  [1, '0', '1'],
#  [1, '1', '1'],
#  [1, '2', '0'],
#  [2, '0', '0'],
#  [2, '1', '1'],
#  [2, '2', '1']]

# %%
ratingtask = agreement.AnnotationTask(data=taskdata)

# %%
ratingtask

# %%
from statsmodels.stats.inter_rater import fleiss_kappa

# %%
fleiss_kappa(np.array(taskdata).astype(int), method='fleiss')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-12-a381c01c882c> in <module>
# ----> 1 fleiss_kappa(np.array(taskdata).astype(int), method='fleiss')
#
# ~/anaconda3/envs/socialMM/lib/python3.7/site-packages/statsmodels/stats/inter_rater.py in fleiss_kappa(table, method)
#     248     n_rat = n_rater.max()
#     249     #assume fully ranked
# --> 250     assert n_total == n_sub * n_rat
#     251
#     252     #marginal frequency  of categories
#
# AssertionError:

# %%
from sklearn.metrics import cohen_kappa_score

coder1 = [1,0,2,0,1,1,2,0,1,1]
coder2 = [1,1,0,0,1,1,2,1,1,0]
score = cohen_kappa_score(coder1,coder2)

print('Cohen\'s Kappa:',score)
# Out:
# Cohen's Kappa: 0.3220338983050848

# %%
r_df = pd.read_csv(os.path.join("../data/stack_files/balanced_pro_n_anti_mask_df_v4_w_ratings.csv"))

# %%
r_df2 = r_df.iloc[:320, :]

# %%
r_df2.columns
# Out:
# Index(['ID', 'CAP6317_rating'], dtype='object')

# %%
df = pd.read_csv("../data/stack_files/balanced_pro_n_anti_mask_df_v4.csv")

# %%
df.shape
# Out:
# (3201, 24)

# %%
m_df = pd.merge(df[df["ID", "ground_truth"]], r_df, on=["ID"], sort=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/socialMM/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('ID', 'ground_truth')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-f5b82e3d245b> in <module>
# ----> 1 m_df = pd.merge(df[df["ID", "ground_truth"]], r_df, on=["ID"], sort=True)
#
# ~/anaconda3/envs/socialMM/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/socialMM/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: ('ID', 'ground_truth')

# %%
x = df[["ID", "ground_truth"]].iloc[:320, :].copy()

# %%
x.head()
# Out:
#                     ID  ground_truth
# 0       0_June_0000412             0
# 1    0_October_0000734             0
# 2  1_September_0000681             1
# 3  1_September_0004729             1
# 4  0_September_0001105             0

# %%
r_df2.shape
# Out:
# (320, 2)

# %%
x.dtypes
# Out:
# ID              object
# ground_truth     int64
# dtype: object

# %%
r_df2.dtypes
# Out:
# ID                object
# CAP6317_rating     int64
# dtype: object

# %%
x["ground_truth"] = x[x["ground_truth"] == 0] = 100

# %%
x.head()
# Out:
#                     ID  ground_truth
# 0       0_June_0000412           100
# 1    0_October_0000734           100
# 2  1_September_0000681           100
# 3  1_September_0004729           100
# 4  0_September_0001105           100

# %%
df_2 = df[["ID", "ground_truth"]]

df_2 = df_2.iloc[:320, :].copy()

# %%
df_2.head()
# Out:
#                     ID  ground_truth
# 0       0_June_0000412             0
# 1    0_October_0000734             0
# 2  1_September_0000681             1
# 3  1_September_0004729             1
# 4  0_September_0001105             0

# %%
df_2["ground_truth"] = df_2["ground_truth"].replace([0], 100)

# %%
df_2.head()
# Out:
#                     ID  ground_truth
# 0       0_June_0000412             5
# 1    0_October_0000734             5
# 2  1_September_0000681             5
# 3  1_September_0004729             5
# 4  0_September_0001105             5

# %%
r_df.shape
# Out:
# (3201, 2)

# %%
df.shape
# Out:
# (3201, 24)

# %%
m_df = pd.merge(r_df, df[["ID", "ground_truth"]].copy(), on=["ID"])

m_df["ground_truth"] = m_df["ground_truth"].astype(bool)

# %%
m_df["ground_truth"] = m_df["ground_truth"].replace({0: 1, 1: 0})

# %%
m_df.head()


m_df = m_df.iloc[:320, :].copy()

# %%
from sklearn.metrics import cohen_kappa_score

# coder1 = [1,0,2,0,1,1,2,0,1,1]
# coder2 = [1,1,0,0,1,1,2,1,1,0]
score = cohen_kappa_score(m_df["ground_truth"], m_df["CAP6317_rating"])

print('Cohen\'s Kappa:',score)
# Out:
# Cohen's Kappa: 0.87998420844848

# %%
m_df.head(20)
# Out:
#                      ID  CAP6317_rating  ground_truth
# 0        0_June_0000412               1             1
# 1     0_October_0000734               1             1
# 2   1_September_0000681               0             0
# 3   1_September_0004729               0             0
# 4   0_September_0001105               1             1
# 5        1_July_0000853               0             0
# 6        1_June_0002499               0             0
# 7        1_July_0004618               0             0
# 8        1_July_0002832               0             0
# 9   0_September_0000180               1             1
# 10     1_August_0003273               0             0
# 11   1_November_0001017               0             0
# 12        0_May_0000186               0             1
# 13       0_June_0000299               1             1
# 14     0_August_0000042               1             1
# 15    1_October_0002149               0             0
# 16       1_June_0003068               0             0
# 17  0_September_0000841               1             1
# 18     1_August_0001410               0             0
# 19       1_July_0003537               0             0

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(m_df["ground_truth"], m_df["CAP6317_rating"])
# Out:
# array([[169,   1],
#        [ 18, 132]])

# %%
m_df["ground_truth"].unique().tolist()
# Out:
# [1, 0]

# %%
m_df["CAP6317_rating"].unique().tolist()
# Out:
# [1, 0, -999]

# %%
m_df.shape
# Out:
# (3201, 3)

# %%
jx_df = pd.read_csv("../data/stack_files/balanced_pro_n_anti_mask_df_v4_labeled_jx.csv")

# %%
jx_df.shape
# Out:
# (3201, 25)

# %%
m_df2 = pd.merge(m_df, jx_df[["ID", "Sarcasm"]].copy(), on=["ID"])

# %%
jx_df.columns
# Out:
# Index(['Tweet Text', 'Sarcasm', 'Tweet Datetime', 'Tweet Id', 'User Id',
#        'User Name', 'User Location', 'Tweet Coordinates', 'Place Info',
#        'Country', 'Hashtags', 'Retweets', 'Favorites', 'Language', 'Source',
#        'Replied Tweet Id', 'Replied Tweet User Id', 'month', 'ground_truth',
#        'ID', 'folds', 'vader_neg', 'vader_neu', 'vader_pos', 'vader_compound'],
#       dtype='object')

# %%
m_df2.head()
# Out:
#                     ID  CAP6317_rating  ground_truth  Sarcasm
# 0       0_June_0000412               1             1      0.0
# 1    0_October_0000734               1             1      0.0
# 2  1_September_0000681               0             0      0.0
# 3  1_September_0004729               0             0      1.0
# 4  0_September_0001105               1             1      0.0

# %%
# m_df2["Sarcasm"] = m_df2["Sarcasm"].replace({0: 1, 1:0})
# m_df2["Sarcasm"] = m_df2["Sarcasm"].astype(int)

m_df2 = m_df2.iloc[:318, :].copy()
m_df2["Sarcasm"] = m_df2["Sarcasm"].astype(int)

m_df2.head(20)
# Out:
#                      ID  CAP6317_rating  ground_truth  Sarcasm
# 0        0_June_0000412               1             1        0
# 1     0_October_0000734               1             1        0
# 2   1_September_0000681               0             0        0
# 3   1_September_0004729               0             0        1
# 4   0_September_0001105               1             1        0
# 5        1_July_0000853               0             0        0
# 6        1_June_0002499               0             0        1
# 7        1_July_0004618               0             0        0
# 8        1_July_0002832               0             0        0
# 9   0_September_0000180               1             1        0
# 10     1_August_0003273               0             0        0
# 11   1_November_0001017               0             0        0
# 12        0_May_0000186               0             1        0
# 13       0_June_0000299               1             1        1
# 14     0_August_0000042               1             1        0
# 15    1_October_0002149               0             0        0
# 16       1_June_0003068               0             0        1
# 17  0_September_0000841               1             1        0
# 18     1_August_0001410               0             0        0
# 19       1_July_0003537               0             0        1

# %%
m_df2.head()
# Out:
#                     ID  CAP6317_rating  ground_truth  Sarcasm
# 0       0_June_0000412               1             1      0.0
# 1    0_October_0000734               1             1      0.0
# 2  1_September_0000681               0             0      0.0
# 3  1_September_0004729               0             0      1.0
# 4  0_September_0001105               1             1      0.0

# %%
print(confusion_matrix(m_df2["ground_truth"], m_df2["Sarcasm"].astype(bool)))


print(cohen_kappa_score(m_df2["CAP6317_rating"], m_df2["Sarcasm"].astype(int)))
# Out:
# [[152  17]
#  [128  21]]
# 0.0446351931330472

# %%
m_df2["Sarcasm"].unique().tolist()
# Out:
# [0.0, 1.0, nan]
